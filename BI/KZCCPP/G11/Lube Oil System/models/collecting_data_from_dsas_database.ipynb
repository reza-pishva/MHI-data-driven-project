# %%
import pyodbc
import pymysql
import time
from datetime import datetime
import threading
import signal
import sys

# ================== تنظیمات ==================
INTERVAL_SECONDS = 60 * 60  # هر 5 دقیقه
RUNNING = True  # برای توقف با Ctrl+C

# ================== اتصالات ==================
def get_sql_connection():
    return pyodbc.connect(
        'DRIVER={SQL Server};'
        'SERVER=10WKS-PISHVA;'
        'DATABASE=PEGAH;'
        'UID=rezapishva;'
        'PWD=5rdx@4rfv1355'
    )

def get_mysql_connection():
    return pymysql.connect(
        host="127.0.0.1", port=3306, user="root", password="", database="dsas",
        charset="utf8mb4", cursorclass=pymysql.cursors.DictCursor
    )

# ================== لیست AssetIDها ==================
asset_ids = [8341, 8342, 8343, 8344, 8346, 9286, 9287]
field_map = {8341: 'AssetID_8341', 8342: 'AssetID_8342', 8343: 'AssetID_8343',
             8344: 'AssetID_8344', 8346: 'AssetID_8346', 9286: 'AssetID_9286', 9287: 'AssetID_9287'}

# ================== تابع اصلی (همون کد قبلی) ==================
def run_task():
    print(f"\n{'='*60}")
    print(f"اجرای وظیفه: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")

    conn_sql = None
    conn_mysql = None
    cursor = None

    try:
        # --- اتصال ---
        print("اتصال به SQL Server...")
        conn_sql = get_sql_connection()
        print("اتصال به MySQL...")
        conn_mysql = get_mysql_connection()

        # --- خواندن TimeStamps موجود ---
        print("خواندن TimeStamps موجود...")
        existing_ts = set()
        with conn_mysql.cursor() as c:
            c.execute("SELECT TimeStamps FROM main_table_mhi_lube_oil_11 WHERE unitID = 11")
            for row in c.fetchall():
                existing_ts.add(row['TimeStamps'])
        print(f"{len(existing_ts)} رکورد موجود است.")

        # --- خواندن 10 رکورد آخر برای 8341 ---
        print("خواندن 10 رکورد آخر برای AssetID=8341...")
        query_8341 = """
        SELECT TOP 1000 [Value], [RecordTime], [RecordDate], [DateTime], [TimeStamp]
        FROM [PEGAH].[PDA].[Periodic_Values]
        WHERE [UnitID] = 11 AND [AssetID] = 8341
        ORDER BY [DateTime] DESC
        """
        cursor = conn_sql.cursor()
        cursor.execute(query_8341)
        rows_8341 = cursor.fetchall()

        if not rows_8341:
            print("هیچ داده‌ای برای AssetID=8341 پیدا نشد.")
            return

        inserted_count = 0
        for idx, row in enumerate(rows_8341):
            ts = row.TimeStamp
            if ts in existing_ts:
                print(f"رکورد {idx+1}: TimeStamps={ts} تکراری → رد شد.")
                continue

            dt = row.DateTime
            print(f"\n--- درج رکورد {idx+1} | TimeStamps={ts} ---")

            # درج اولیه
            insert_sql = """
            INSERT INTO main_table_mhi_lube_oil_11
            (unitID, AssetID_8341, RecordTime, RecordDate, DateTime, TimeStamps)
            VALUES (%s, %s, %s, %s, %s, %s)
            """
            try:
                with conn_mysql.cursor() as c:
                    c.execute(insert_sql, (11, row.Value, 
                                         dt.strftime('%H:%M:%S'), dt.strftime('%Y-%m-%d'), dt, ts))
                conn_mysql.commit()
                print("رکورد درج شد.")
                inserted_count += 1
            except Exception as e:
                print(f"خطا در درج: {e}")
                continue

            # آپدیت 6 فیلد دیگر
            for aid in [8342, 8343, 8344, 8346, 9286, 9287]:
                field = field_map[aid]
                near_sql = f"""
                SELECT TOP 1 [Value] FROM [PEGAH].[PDA].[Periodic_Values]
                WHERE [UnitID]=11 AND [AssetID]=? AND ABS([TimeStamp] - ?) < 1000
                ORDER BY ABS([TimeStamp] - ?)
                """
                cursor.execute(near_sql, (aid, ts, ts))
                near_row = cursor.fetchone()

                if near_row and near_row.Value is not None:
                    value = float(near_row.Value)
                    source = "نزدیک"
                else:
                    avg_sql = f"""
                    SELECT AVG(CAST([Value] AS FLOAT)) FROM (
                        SELECT TOP 10 [Value] FROM [PEGAH].[PDA].[Periodic_Values]
                        WHERE [UnitID]=11 AND [AssetID]=?
                        ORDER BY [DateTime] DESC
                    ) sub
                    """
                    cursor.execute(avg_sql, (aid,))
                    avg_row = cursor.fetchone()
                    value = round(float(avg_row[0]), 4) if avg_row and avg_row[0] else None
                    source = "میانگین"

                if value is not None:
                    update_sql = f"UPDATE main_table_mhi_lube_oil_11 SET {field} = %s WHERE TimeStamps = %s"
                    try:
                        with conn_mysql.cursor() as c:
                            c.execute(update_sql, (value, ts))
                        conn_mysql.commit()
                        print(f"   {field} = {value} ({source})")
                    except Exception as e:
                        print(f"   خطا در آپدیت {field}: {e}")
                else:
                    print(f"   {field}: داده‌ای پیدا نشد.")

        print(f"\nنتیجه این دور: {inserted_count} رکورد جدید درج و آپدیت شد.")

    except Exception as e:
        print(f"خطای کلی: {e}")
    finally:
        if cursor: cursor.close()
        if conn_sql: conn_sql.close()
        if conn_mysql: conn_mysql.close()

# ================== حلقه اصلی (هر 5 دقیقه) ==================
def scheduler():
    run_task()
    # while RUNNING:
    #     run_task()
    #     print(f"\nمنتظر {INTERVAL_SECONDS//60} دقیقه بعدی...")
    #     # خوابیدن با چک کردن هر ثانیه (برای Ctrl+C)
    #     for _ in range(INTERVAL_SECONDS):
    #         if not RUNNING:
    #             break
    #         time.sleep(1)

# ================== توقف با Ctrl+C ==================
def signal_handler(sig, frame):
    global RUNNING
    print('\nدریافت سیگنال توقف (Ctrl+C). در حال خروج...')
    RUNNING = False

signal.signal(signal.SIGINT, signal_handler)

# ================== اجرا ==================
if __name__ == "__main__":
    print("اسکریپت هر 60 دقیقه یکبار اجرا میشود...")
    print("برای توقف، Ctrl+C بزنید.")
    scheduler()
    print("اسکریپت با موفقیت متوقف شد.")
# Out:
# اسکریپت هر 60 دقیقه یکبار اجرا میشود...
# برای توقف، Ctrl+C بزنید.
#
# ============================================================
# اجرای وظیفه: 2025-11-14 16:52:47
# ============================================================
# اتصال به SQL Server...
# اتصال به MySQL...
# خواندن TimeStamps موجود...
# 0 رکورد موجود است.
# خواندن 10 رکورد آخر برای AssetID=8341...
#
# --- درج رکورد 1 | TimeStamps=1701564893 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 2 | TimeStamps=1701550623 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 3 | TimeStamps=1701537147 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 4 | TimeStamps=1701521363 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 5 | TimeStamps=1701507631 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد
---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 171 | TimeStamps=1699299676 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 172 | TimeStamps=1699292416 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 173 | TimeStamps=1699280204 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 174 | TimeStamps=1699280204 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 175 | TimeStamps=1699268287 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 176 | TimeStamps=1699268287 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 177 | TimeStamps=1699257579 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 178 | TimeStamps=1699257579 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 179 | TimeStamps=1699248143 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 67.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 180 | TimeStamps=1699235849 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 181 | TimeStamps=1699224688 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 182 | TimeStamps=1699213801 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 183 | TimeStamps=1699205831 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 184 | TimeStamps=1699191709 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 185 | TimeStamps=1699180986 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 186 | TimeStamps=1699171969 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 187 | TimeStamps=1699162056 ---
# رکورد درج شد.
#    AssetID_8342 = 11.95 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.3 (نزدیک)
#
# --- درج رکورد 188 | TimeStamps=1699151808 ---
# رکورد درج شد.
#    AssetID_8342 = 11.95 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 189 | TimeStamps=1699137504 ---
# رکورد درج شد.
#    AssetID_8342 = 11.95 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 190 | TimeStamps=1699127256 ---
# رکورد درج شد.
#    AssetID_8342 = 11.95 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 191 | TimeStamps=1699118769 ---
# رکورد درج شد.
#    AssetID_8342 = 11.95 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -235.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 192 | TimeStamps=1699105925 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 193 | TimeStamps=1699096107 ---
# رکورد درج شد.
#    AssetID_8342 = 11.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.3 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 194 | TimeStamps=1699084849 ---
# رکورد درج شد.
# ...
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 937 | TimeStamps=1692270571 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 938 | TimeStamps=1692258413 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 939 | TimeStamps=1692247910 ---
# رکورد درج شد.
#    AssetID_8342 = 12.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 940 | TimeStamps=1692239092 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 68.5 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 941 | TimeStamps=1692226033 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 942 | TimeStamps=1692216008 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 943 | TimeStamps=1692205194 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 944 | TimeStamps=1692194908 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 945 | TimeStamps=1692182167 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 946 | TimeStamps=1692173301 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 947 | TimeStamps=1692162593 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 948 | TimeStamps=1692152166 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 949 | TimeStamps=1692139056 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 950 | TimeStamps=1692129300 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 951 | TimeStamps=1692118526 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 952 | TimeStamps=1692108061 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 953 | TimeStamps=1692098278 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 954 | TimeStamps=1692089899 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 955 | TimeStamps=1692089899 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 956 | TimeStamps=1692076587 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -225.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 957 | TimeStamps=1692064455 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 958 | TimeStamps=1692052549 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 959 | TimeStamps=1692052549 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 960 | TimeStamps=1692041658 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 961 | TimeStamps=1692041658 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 962 | TimeStamps=1692031467 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 963 | TimeStamps=1692031467 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 964 | TimeStamps=1692021362 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 965 | TimeStamps=1692010017 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 75.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 966 | TimeStamps=1691999469 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.26 (نزدیک)
#
# --- درج رکورد 967 | TimeStamps=1691988864 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 968 | TimeStamps=1691981165 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 969 | TimeStamps=1691968027 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 970 | TimeStamps=1691968027 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 971 | TimeStamps=1691956037 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 972 | TimeStamps=1691956037 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 973 | TimeStamps=1691948815 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 974 | TimeStamps=1691948815 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 975 | TimeStamps=1691936031 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 976 | TimeStamps=1691925300 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 977 | TimeStamps=1691925300 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 978 | TimeStamps=1691914229 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 979 | TimeStamps=1691914229 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 980 | TimeStamps=1691902516 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 981 | TimeStamps=1691902516 ---
# رکورد درج شد.
#    AssetID_8342 = 12.2 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.1 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 982 | TimeStamps=1691892533 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 983 | TimeStamps=1691883181 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 984 | TimeStamps=1691869710 ---
# رکورد درج شد.
#    AssetID_8342 = 12.3 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 985 | TimeStamps=1691858492 ---
# رکورد درج شد.
#    AssetID_8342 = 12.4 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 986 | TimeStamps=1691849992 ---
# رکورد درج شد.
#    AssetID_8342 = 12.4 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 987 | TimeStamps=1691841520 ---
# رکورد درج شد.
#    AssetID_8342 = 12.4 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 988 | TimeStamps=1691826851 ---
# رکورد درج شد.
#    AssetID_8342 = 12.0 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.27 (نزدیک)
#
# --- درج رکورد 989 | TimeStamps=1691816528 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 990 | TimeStamps=1691804780 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 991 | TimeStamps=1691794079 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 992 | TimeStamps=1691782963 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 993 | TimeStamps=1691772724 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.8 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 994 | TimeStamps=1691762283 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.26 (نزدیک)
#
# --- درج رکورد 995 | TimeStamps=1691751241 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 75.5 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.26 (نزدیک)
#
# --- درج رکورد 996 | TimeStamps=1691740969 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.26 (نزدیک)
#
# --- درج رکورد 997 | TimeStamps=1691734444 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.9 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 998 | TimeStamps=1691719242 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 999 | TimeStamps=1691707074 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 1000 | TimeStamps=1691696020 ---
# رکورد درج شد.
#    AssetID_8342 = 11.6 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 7.0 (نزدیک)
#    AssetID_9286 = 7.2 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# نتیجه این دور: 1000 رکورد جدید درج و آپدیت شد.
# اسکریپت با موفقیت متوقف شد.
