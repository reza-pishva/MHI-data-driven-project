# %%
import pyodbc
import pymysql
import time
from datetime import datetime
import threading
import signal
import sys

# ================== تنظیمات ==================
INTERVAL_SECONDS = 60 * 60  # هر 5 دقیقه
RUNNING = True  # برای توقف با Ctrl+C

# ================== اتصالات ==================
def get_sql_connection():
    return pyodbc.connect(
    'DRIVER={SQL Server};'
    'SERVER=MKZ-DSAS\\DSAS;'
    'DATABASE=DSAS;'
    'UID=datadriven;'
    'PWD=5Rdx@4Rfv1355'
    )

def get_mysql_connection():
    return pymysql.connect(
        host="127.0.0.1", port=3306, user="root", password="", database="dsas",
        charset="utf8mb4", cursorclass=pymysql.cursors.DictCursor
    )

# ================== لیست AssetIDها ==================
asset_ids = [8341, 8342, 8343, 8344, 8346, 9286, 9287]
field_map = {8341: 'AssetID_8341', 8342: 'AssetID_8342', 8343: 'AssetID_8343',
             8344: 'AssetID_8344', 8346: 'AssetID_8346', 9286: 'AssetID_9286', 9287: 'AssetID_9287'}

# ================== تابع اصلی (همون کد قبلی) ==================
def run_task():
    print(f"\n{'='*60}")
    print(f"اجرای وظیفه: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")

    conn_sql = None
    conn_mysql = None
    cursor = None

    try:
        # --- اتصال ---
        print("اتصال به SQL Server...")
        conn_sql = get_sql_connection()
        print("اتصال به MySQL...")
        conn_mysql = get_mysql_connection()

        # --- خواندن TimeStamps موجود ---
        print("خواندن TimeStamps موجود...")
        existing_ts = set()
        with conn_mysql.cursor() as c:
            c.execute("SELECT TimeStamps FROM main_table_mhi_lube_oil_11 WHERE unitID = 11")
            for row in c.fetchall():
                existing_ts.add(row['TimeStamps'])
        print(f"{len(existing_ts)} رکورد موجود است.")

        # --- خواندن 10 رکورد آخر برای 8341 ---
        print("خواندن 10 رکورد آخر برای AssetID=8341...")
        query_8341 = """
        SELECT TOP 12000 [Value], [RecordTime], [RecordDate], [DateTime], [TimeStamp]
        FROM [DSAS].[PDA].[Periodic_Values]
        WHERE [UnitID] = 11 AND [AssetID] = 8341
        ORDER BY [DateTime] DESC
        """
        cursor = conn_sql.cursor()
        cursor.execute(query_8341)
        rows_8341 = cursor.fetchall()

        if not rows_8341:
            print("هیچ داده‌ای برای AssetID=8341 پیدا نشد.")
            return

        inserted_count = 0
        for idx, row in enumerate(rows_8341):
            ts = row.TimeStamp
            if ts in existing_ts:
                print(f"رکورد {idx+1}: TimeStamps={ts} تکراری → رد شد.")
                continue

            dt = row.DateTime
            print(f"\n--- درج رکورد {idx+1} | TimeStamps={ts} ---")

            # درج اولیه
            insert_sql = """
            INSERT INTO main_table_mhi_lube_oil_11
            (unitID, AssetID_8341, RecordTime, RecordDate, DateTime, TimeStamps)
            VALUES (%s, %s, %s, %s, %s, %s)
            """
            try:
                with conn_mysql.cursor() as c:
                    c.execute(insert_sql, (11, row.Value, 
                                         dt.strftime('%H:%M:%S'), dt.strftime('%Y-%m-%d'), dt, ts))
                conn_mysql.commit()
                print("رکورد درج شد.")
                inserted_count += 1
            except Exception as e:
                print(f"خطا در درج: {e}")
                continue

            # آپدیت 6 فیلد دیگر
            for aid in [8342, 8343, 8344, 8346, 9286, 9287]:
                field = field_map[aid]
                near_sql = f"""
                SELECT TOP 1 [Value] FROM [DSAS].[PDA].[Periodic_Values]
                WHERE [UnitID]=11 AND [AssetID]=? AND ABS([TimeStamp] - ?) < 1000
                ORDER BY ABS([TimeStamp] - ?)
                """
                cursor.execute(near_sql, (aid, ts, ts))
                near_row = cursor.fetchone()

                if near_row and near_row.Value is not None:
                    value = float(near_row.Value)
                    source = "نزدیک"
                else:
                    avg_sql = f"""
                    SELECT AVG(CAST([Value] AS FLOAT)) FROM (
                        SELECT TOP 10 [Value] FROM [DSAS].[PDA].[Periodic_Values]
                        WHERE [UnitID]=11 AND [AssetID]=?
                        ORDER BY [DateTime] DESC
                    ) sub
                    """
                    cursor.execute(avg_sql, (aid,))
                    avg_row = cursor.fetchone()
                    value = round(float(avg_row[0]), 4) if avg_row and avg_row[0] else None
                    source = "میانگین"

                if value is not None:
                    update_sql = f"UPDATE main_table_mhi_lube_oil_11 SET {field} = %s WHERE TimeStamps = %s"
                    try:
                        with conn_mysql.cursor() as c:
                            c.execute(update_sql, (value, ts))
                        conn_mysql.commit()
                        print(f"   {field} = {value} ({source})")
                    except Exception as e:
                        print(f"   خطا در آپدیت {field}: {e}")
                else:
                    print(f"   {field}: داده‌ای پیدا نشد.")

        print(f"\nنتیجه این دور: {inserted_count} رکورد جدید درج و آپدیت شد.")

    except Exception as e:
        print(f"خطای کلی: {e}")
    finally:
        if cursor: cursor.close()
        if conn_sql: conn_sql.close()
        if conn_mysql: conn_mysql.close()

# ================== حلقه اصلی (هر 5 دقیقه) ==================
def scheduler():
    run_task()
    # while RUNNING:
    #     run_task()
    #     print(f"\nمنتظر {INTERVAL_SECONDS//60} دقیقه بعدی...")
    #     # خوابیدن با چک کردن هر ثانیه (برای Ctrl+C)
    #     for _ in range(INTERVAL_SECONDS):
    #         if not RUNNING:
    #             break
    #         time.sleep(1)

# ================== توقف با Ctrl+C ==================
def signal_handler(sig, frame):
    global RUNNING
    print('\nدریافت سیگنال توقف (Ctrl+C). در حال خروج...')
    RUNNING = False

signal.signal(signal.SIGINT, signal_handler)

# ================== اجرا ==================
if __name__ == "__main__":
    print("اسکریپت هر 60 دقیقه یکبار اجرا میشود...")
    print("برای توقف، Ctrl+C بزنید.")
    scheduler()
    print("اسکریپت با موفقیت متوقف شد.")
# Out:
# اسکریپت هر 60 دقیقه یکبار اجرا میشود...
# برای توقف، Ctrl+C بزنید.
#
# ============================================================
# اجرای وظیفه: 2025-11-19 14:26:01
# ============================================================
# اتصال به SQL Server...
# اتصال به MySQL...
# خواندن TimeStamps موجود...
# 10806 رکورد موجود است.
# خواندن 10 رکورد آخر برای AssetID=8341...
# رکورد 1: TimeStamps=1763340043 تکراری → رد شد.
# رکورد 2: TimeStamps=1763325657 تکراری → رد شد.
# رکورد 3: TimeStamps=1763311996 تکراری → رد شد.
# رکورد 4: TimeStamps=1763298469 تکراری → رد شد.
# رکورد 5: TimeStamps=1763282014 تکراری → رد شد.
# رکورد 6: TimeStamps=1763269510 تکراری → رد شد.
# رکورد 7: TimeStamps=1763259119 تکراری → رد شد.
# رکورد 8: TimeStamps=1763239246 تکراری → رد شد.
# رکورد 9: TimeStamps=1763225924 تکراری → رد شد.
# رکورد 10: TimeStamps=1763210597 تکراری → رد شد.
# رکورد 11: TimeStamps=1763196598 تکراری → رد شد.
# رکورد 12: TimeStamps=1763182451 تکراری → رد شد.
# رکورد 13: TimeStamps=1763172992 تکراری → رد شد.
# رکورد 14: TimeStamps=1763153044 تکراری → رد شد.
# رکورد 15: TimeStamps=1763140569 تکراری → رد شد.
# رکورد 16: TimeStamps=1763127443 تکراری → رد شد.
# رکورد 17: TimeStamps=1763109282 تکراری → رد شد.
# رکورد 18: TimeStamps=1763098032 تکراری → رد شد.
# رکورد 19: TimeStamps=1763086121 تکراری → رد شد.
# رکورد 20: TimeStamps=1763066364 تکراری → رد شد.
# رکورد 21: TimeStamps=1763054737 تکراری → رد شد.
# رکورد 22: TimeStamps=1763039409 تکراری → رد شد.
# رکورد 23: TimeStamps=1763023200 تکراری → رد شد.
# رکورد 24: TimeStamps=1763012230 تکراری → رد شد.
# رکورد 25: TimeStamps=1762997389 تکراری → رد شد.
# رکورد 26: TimeStamps=1762980399 تکراری → رد شد.
# رکورد 27: TimeStamps=1762967091 تکراری → رد شد.
# رکورد 28: TimeStamps=1762952877 تکراری → رد شد.
# رکورد 29: TimeStamps=1762936759 تکراری → رد شد.
# رکورد 30: TimeStamps=1762925198 تکراری → رد شد.
# رکورد 31: TimeStamps=1762913573 تکراری → رد شد.
# رکورد 32: TimeStamps=1762894149 تکراری → رد شد.
# رکورد 33: TimeStamps=1762882910 تکراری → رد شد.
# رکورد 34: TimeStamps=1762866265 تکراری → رد شد.
# رکورد 35: TimeStamps=1762850805 تکراری → رد شد.
# رکورد 36: TimeStamps=1762837605 تکراری → رد شد.
# رکورد 37: TimeStamps=1762827357 تکراری → رد شد.
# رکورد 38: TimeStamps=1762807782 تکراری → رد شد.
# رکورد 39: TimeStamps=1762797257 تکراری → رد شد.
# رکورد 40: TimeStamps=1762782122 تکراری → رد شد.
# رکورد 41: TimeStamps=1762764333 تکراری → رد شد.
# رکورد 42: TimeStamps=1762751283 تکراری → رد شد.
# رکورد 43: TimeStamps=1762739370 تکراری → رد شد.
# رکورد 44: TimeStamps=1762720987 تکراری → رد شد.
# رکورد 45: TimeStamps=1762707713 تکراری → رد شد.
# رکورد 46: TimeStamps=1762697230 تکراری → رد شد.
# رکورد 47: TimeStamps=1762677744 تکراری → رد شد.
# رکورد 48: TimeStamps=1762666163 تکراری → رد شد.
# رکورد 49: TimeStamps=1762648878 تکراری → رد شد.
# رکورد 50: TimeStamps=1762634820 تکراری → رد شد.
# رکورد 51: TimeStamps=1762620914 تکراری → رد شد.
# رکورد 52: TimeStamps=1762605898 تکراری → رد شد.
# رکورد 53: TimeStamps=1762591088 تکراری → رد شد.
# رکورد 54: TimeStamps=1762578252 تکراری → رد شد.
# رکورد 55: TimeStamps=1762567897 تکراری → رد شد.
# رکورد 56: TimeStamps=1762548052 تکراری → رد شد.
# رکورد 57: TimeStamps=1762534769 تکراری → رد شد.
# رکورد 58: TimeStamps=1762519371 تکراری → رد شد.
# رکورد 59: TimeStamps=1762505567 تکراری → رد شد.
# رکورد 60: TimeStamps=1762492445 تکراری → رد شد.
# رکورد 61: TimeStamps=1762481703 تکراری → رد شد.
# رکورد 62: TimeStamps=1762461453 تکراری → رد شد.
# رکورد 63: TimeStamps=1762451928 تکراری → رد شد.
# رکورد 64: TimeStamps=1762436907 تکراری → رد شد.
# رکورد 65: TimeStamps=1762418428 تکراری → رد شد.
# رکورد 66: TimeStamps=1762406047 تکراری → رد شد.
# رکورد 67: TimeStamps=1762395320 تکراری → رد شد.
# رکورد 68: TimeStamps=1762375098 تکراری → رد شد.
# رکورد 69: TimeStamps=1762363401 تکراری → رد شد.
# رکورد 70: TimeStamps=1762350621 تکراری → رد شد.
# رکورد 71: TimeStamps=1762331676 تکراری → رد شد.
# رکورد 72: TimeStamps=1762319714 تکراری → رد شد.
# رکورد 73: TimeStamps=1762304873 تکراری → رد شد.
# رکورد 74: TimeStamps=1762289160 تکراری → رد شد.
# رکورد 75: TimeStamps=1762275976 تکراری → رد شد.
# رکورد 76: TimeStamps=1762265261 تکراری → رد شد.
# رکورد 77: TimeStamps=1762245654 تکراری → رد شد.
# رکورد 78: TimeStamps=1762233102 تکراری → رد شد.
# رکورد 79: TimeStamps=1762220674 تکراری → رد شد.
# رکورد 80: TimeStamps=1762202503 تکراری → رد شد.
# رکورد 81: TimeStamps=1762190435 تکراری → رد شد.
# رکورد 82: TimeStamps=1762174400 تکراری → رد شد.
# رکورد 83: TimeStamps=1762146671 تکراری → رد شد.
# رکورد 84: TimeStamps=1762136392 تکراری → رد شد.
# رکورد 85: TimeStamps=1762116436 تکراری → رد شد.
# رکورد 86: TimeStamps=1762106068 تکراری → رد شد.
# رکورد 87: TimeStamps=1762090249 تکراری → رد شد.
# رکورد 88: TimeStamps=1762072430 تکراری → رد شد.
# رکورد 89: TimeStamps=1762061593 تکراری → رد شد.
# رکورد 90: TimeStamps=1762048083 تکراری → رد شد.
# رکورد 91: TimeStamps=1762029806 تکراری → رد شد.
# رکورد 92: TimeStamps=1762017639 تکراری → رد شد.
# رکورد 93: TimeStamps=1762003755 تکراری → رد شد.
# رکورد 94: TimeStamps=1761987246 تکراری → رد شد.
# رکورد 95: TimeStamps=1761975881 تکراری → رد شد.
# رکورد 96: TimeStamps=1761957740 تکراری → رد شد.
# رکورد 97: TimeStamps=1761943403 تکراری → رد شد.
# رکورد 98: TimeStamps=1761929519 تکراری → رد شد.
# رکورد 99: TimeStamps=1761915439 تکراری → رد شد.
# رکورد 100: TimeStamps=1761899965 تکراری → رد شد.
# رکورد 101: TimeStamps=1761886861 تکراری → رد شد.
# رکورد 102: TimeStamps=1761877190 تکراری → رد شد.
# رکورد 103: TimeStamps=1761857434 تکراری → رد شد.
# رکورد 104: TimeStamps=1761842437 تکراری → رد شد.
# رکورد 105: TimeStamps=1761828708 تکراری → رد شد.
# رکورد 106: TimeStamps=1761814228 تکراری → رد شد.
# رکورد 107: TimeStamps=1761800047 تکراری → رد شد.
# رکورد 108: TimeStamps=1761790908 تکراری → رد شد.
# رکورد 109: TimeStamps=1761770186 تکراری → رد شد.
# رکورد 110: TimeStamps=1761760555 تکراری → رد شد.
# رکورد 111: TimeStamps=1761744383 تکراری → رد شد.
# رکورد 112: TimeStamps=1761727612 تکراری → رد شد.
# رکورد 113: TimeStamps=1761713757 تکراری → رد شد.
# رکورد 114: TimeStamps=1761704130 تکراری → رد شد.
# رکورد 115: TimeStamps=1761684348 تکراری → رد شد.
# رکورد 116: TimeStamps=1761669708 تکراری → رد شد.
# رکورد 117: TimeStamps=1761659200 تکراری → رد شد.
# رکورد 118: TimeStamps=1761642680 تکراری → رد شد.
# رکورد 119: TimeStamps=1761629572 تکراری → رد شد.
# رکورد 120: TimeStamps=1761614651 تکراری → رد شد.
# رکورد 121: TimeStamps=1761598146 تکراری → رد شد.
# رکورد 122: TimeStamps=1761584314 تکراری → رد شد.
# رکورد 123: TimeStamps=1761571109 تکراری → رد شد.
# رکورد 124: TimeStamps=1761554665 تکراری → رد شد.
# رکورد 125: TimeStamps=1761542363 تکراری → رد شد.
# رکورد 126: TimeStamps=1761531130 تکراری → رد شد.
# رکورد 127: TimeStamps=1761514137 تکراری → رد شد.
# رکورد 128: TimeStamps=1761498067 تکراری → رد شد.
# رکورد 129: TimeStamps=1761483109 تکراری → رد شد.
# رکورد 130: TimeStamps=1761468641 تکراری → رد شد.
# رکورد 131: TimeStamps=1761455372 تکراری → رد شد.
# رکورد 132: TimeStamps=1761444328 تکراری → رد شد.
# رکورد 133: TimeStamps=1761424637 تکراری → رد شد.
# رکورد 134: TimeStamps=1761413333 تکراری → رد شد.
# رکورد 135: TimeStamps=1761397936 تکراری → رد شد.
# رکورد 136: TimeStamps=1761381828 تکراری → رد شد.
# رکورد 137: TimeStamps=1761369212 تکراری → رد شد.
# رکورد 138: TimeStamps=1761357989 تکراری → رد شد.
# رکورد 139: TimeStamps=1761338657 تکراری → رد شد.
# رکورد 140: TimeStamps=1761323678 تکراری → رد شد.
# رکورد 141: TimeStamps=1761310613 تکراری → رد شد.
# رکورد 142: TimeStamps=1761295567 تکراری → رد شد.
# رکورد 143: TimeStamps=1761284386 تکراری → رد شد.
# رکورد 144: TimeStamps=1761270949 تکراری → رد شد.
# رکورد 145: TimeStamps=1761252275 تکراری → رد شد.
# رکورد 146: TimeStamps=1761238549 تکراری → رد شد.
# رکورد 147: TimeStamps=1761224689 تکراری → رد شد.
# رکورد 148: TimeStamps=1761209062 تکراری → رد شد.
# رکورد 149: TimeStamps=1761196253 تکراری → رد شد.
# رکورد 150: TimeStamps=1761183829 تکراری → رد شد.
# رکورد 151: TimeStamps=1761165658 تکراری → رد شد.
# رکورد 152: TimeStamps=1761152465 تکراری → رد شد.
# رکورد 153: TimeStamps=1761137263 تکراری → رد شد.
# رکورد 154: TimeStamps=1761122746 تکراری → رد شد.
# رکورد 155: TimeStamps=1761108962 تکراری → رد شد.
# رکورد 156: TimeStamps=1761095317 تکراری → رد شد.
# رکورد 157: TimeStamps=1761079055 تکراری → رد شد.
# رکورد 158: TimeStamps=1761068800 تکراری → رد شد.
# رکورد 159: TimeStamps=1761053146 تکراری → رد شد.
# رکورد 160: TimeStamps=1761036534 تکراری → رد شد.
# رکورد 161: TimeStamps=1761023217 تکراری → رد شد.
# رکورد 162: TimeStamps=1761012655 تکراری → رد شد.
# رکورد 163: TimeStamps=1760992801 تکراری → رد شد.
# رکورد 164: TimeStamps=1760978799 تکراری → رد شد.
# رکورد 165: TimeStamps=1760966487 تکراری → رد شد.
# رکورد 166: TimeStamps=1760950439 تکراری → رد شد.
# رکورد 167: TimeStamps=1760940276 تکراری → رد شد.
# رکورد 168: TimeStamps=1760920799 تکراری → رد شد.
# رکورد 169: TimeStamps=1760906573 تکراری → رد شد.
# رکورد 170: TimeStamps=1760893047 تکراری → رد شد.
# رکورد 171: TimeStamps=1760877835 تکراری → رد شد.
# رکورد 172: TimeStamps=1760862972 تکراری → رد شد.
# رکورد 173: TimeStamps=1760853020 تکراری → رد شد.
# رکورد 174: TimeStamps=1760840174 تکراری → رد شد.
# رکورد 175: TimeStamps=1760820459 تکراری → رد شد.
# رکورد 176: TimeStamps=1760806848 تکراری → رد شد.
# رکورد 177: TimeStamps=1760792391 تکراری → رد شد.
# رکورد 178: TimeStamps=1760776384 تکراری → رد شد.
# رکورد 179: TimeStamps=1760766088 تکراری → رد شد.
# رکورد 180: TimeStamps=1760754137 تکراری → رد شد.
# رکورد 181: TimeStamps=1760733655 تکراری → رد شد.
# رکورد 182: TimeStamps=1760723620 تکراری → رد شد.
# رکورد 183: TimeStamps=1760707943 تکراری → رد شد.
# رکورد 184: TimeStamps=1760690248 تکراری → رد شد.
# رکورد 185: TimeStamps=1760677259 تکراری → رد شد.
# رکورد 186: TimeStamps=1760663819 تکراری → رد شد.
# رکورد 187: TimeStamps=1760647771 تکراری → رد شد.
# رکورد 188: TimeStamps=1760633884 تکراری → رد شد.
# رکورد 189: TimeStamps=1760622788 تکراری → رد شد.
# رکورد 190: TimeStamps=1760604205 تکراری → رد شد.
# رکورد 191: TimeStamps=1760592996 تکراری → رد شد.
# رکورد 192: TimeStamps=1760575411 تکراری → رد شد.
# رکورد 193: TimeStamps=1760562586 تکراری → رد شد.
# رکورد 194: TimeStamps=1760547393 تکراری → رد شد.
# رکورد 195: TimeStamps=1760532090 تکراری → رد شد.
# رکورد 196: TimeStamps=1760517876 تکراری → رد شد.
# رکورد 197: TimeStamps=1760505626 تکراری → رد شد.
# رکورد 198: TimeStamps=1760494374 تکراری → رد شد.
# رکورد 199: TimeStamps=1760474243 تکراری → رد شد.
# رکورد 200: TimeStamps=1760462476 تکراری → رد شد.
# رکورد 201: TimeStamps=1760448279 تکراری → رد شد.
# رکورد 202: TimeStamps=1760431349 تکراری → رد شد.
# رکورد 203: TimeStamps=1760417678 تکراری → رد شد.
# رکورد 204: TimeStamps=1760405311 تکراری → رد شد.
# رکورد 205: TimeStamps=1760388061 تکراری → رد شد.
# رکورد 206: TimeStamps=1760377023 تکراری → رد شد.
# رکورد 207: TimeStamps=1760361865 تکراری → رد شد.
# رکورد 208: TimeStamps=1760344860 تکراری → رد شد.
# رکورد 209: TimeStamps=1760332515 تکراری → رد شد.
# رکورد 210: TimeStamps=1760321513 تکراری → رد شد.
# رکورد 211: TimeStamps=1760301557 تکراری → رد شد.
# رکورد 212: TimeStamps=1760287792 تکراری → رد شد.
# رکورد 213: TimeStamps=1760275624 تکراری → رد شد.
# رکورد 214: TimeStamps=1760258855 تکراری → رد شد.
# رکورد 215: TimeStamps=1760248207 تکراری → رد شد.
# رکورد 216: TimeStamps=1760232274 تکراری → رد شد.
# رکورد 217: TimeStamps=1760215751 تکراری → رد شد.
# رکورد 218: TimeStamps=1760202134 تکراری → رد شد.
# رکورد 219: TimeStamps=1760188482 تکراری → رد شد.
# رکورد 220: TimeStamps=1760171983 تکراری → رد شد.
# رکورد 221: TimeStamps=1760160245 تکراری → رد شد.
# رکورد 222: TimeStamps=1760146869 تکراری → رد شد.
# رکورد 223: TimeStamps=1760128873 تکراری → رد شد.
# رکورد 224: TimeStamps=1760114654 تکراری → رد شد.
# رکورد 225: TimeStamps=1760099758 تکراری → رد شد.
# رکورد 226: TimeStamps=1760089504 تکراری → رد شد.
# رکورد 227: TimeStamps=1760073157 تکراری → رد شد.
# رکورد 228: TimeStamps=1760062959 تکراری → رد شد.
# رکورد 229: TimeStamps=1760042442 تکراری → رد شد.
# رکورد 230: TimeStamps=1760029435 تکراری → رد شد.
# رکورد 231: TimeStamps=1760016992 تکراری → رد شد.
# رکورد 232: TimeStamps=1759999475 تکراری → رد شد.
# رکورد 233: TimeStamps=1759986747 تکراری → رد شد.
# رکورد 234: TimeStamps=1759974458 تکراری → رد شد.
# رکورد 235: TimeStamps=1759956379 تکراری → رد شد.
# رکورد 236: TimeStamps=1759943368 تکراری → رد شد.
# رکورد 237: TimeStamps=1759930685 تکراری → رد شد.
# رکورد 238: TimeStamps=1759913242 تکراری → رد شد.
# رکورد 239: TimeStamps=1759901049 تکراری → رد شد.
# رکورد 240: TimeStamps=1759884157 تکراری → رد شد.
# رکورد 241: TimeStamps=1759869737 تکراری → رد شد.
# رکورد 242: TimeStamps=1759856214 تکراری → رد شد.
# رکورد 243: TimeStamps=1759844355 تکراری → رد شد.
# رکورد 244: TimeStamps=1759827314 تکراری → رد شد.
# رکورد 245: TimeStamps=1759813895 تکراری → رد شد.
# رکورد 246: TimeStamps=1759801117 تکراری → رد شد.
# رکورد 247: TimeStamps=1759783258 تکراری → رد شد.
# رکورد 248: TimeStamps=1759769186 تکراری → رد شد.
# رکورد 249: TimeStamps=1759754775 تکراری → رد شد.
# رکورد 250: TimeStamps=1759740571 تکراری → رد شد.
# رکورد 251: TimeStamps=1759727104 تکراری → رد شد.
# رکورد 252: TimeStamps=1759717502 تکراری → رد شد.
# رکورد 253: TimeStamps=1759696905 تکراری → رد شد.
# رکورد 254: TimeStamps=1759686257 تکراری → رد شد.
# رکورد 255: TimeStamps=1759671254 تکراری → رد شد.
# رکورد 256: TimeStamps=1759655171 تکراری → رد شد.
# رکورد 257: TimeStamps=1759639834 تکراری → رد شد.
# رکورد 258: TimeStamps=1759630402 تکراری → رد شد.
# رکورد 259: TimeStamps=1759610540 تکراری → رد شد.
# رکورد 260: TimeStamps=1759598213 تکراری → رد شد.
# رکورد 261: TimeStamps=1759582906 تکراری → رد شد.
# رکورد 262: TimeStamps=1759567803 تکراری → رد شد.
# رکورد 263: TimeStamps=1759556517 تکراری → رد شد.
# رکورد 264: TimeStamps=1759541805 تکراری → رد شد.
# رکورد 265: TimeStamps=1759524367 تکراری → رد شد.
# رکورد 266: TimeStamps=1759510963 تکراری → رد شد.
# رکورد 267: TimeStamps=1759497910 تکراری → رد شد.
# رکورد 268: TimeStamps=1759480633 تکراری → رد شد.
# رکورد 269: TimeStamps=1759469749 تکراری → رد شد.
# رکورد 270: TimeStamps=1759455471 تکراری → رد شد.
# رکورد 271: TimeStamps=1759437984 تکراری → رد شد.
# رکورد 272: TimeStamps=1759424738 تکراری → رد شد.
# رکورد 273: TimeStamps=1759410062 تکراری → رد شد.
# رکورد 274: TimeStamps=1759394525 تکراری → رد شد.
# رکورد 275: TimeStamps=1759381877 تکراری → رد شد.
# رکورد 276: TimeStamps=1759371200 تکراری → رد شد.
# رکورد 277: TimeStamps=1759351059 تکراری → رد شد.
# رکورد 278: TimeStamps=1759337834 تکراری → رد شد.
# رکورد 279: TimeStamps=1759322839 تکراری → رد شد.
# رکورد 280: TimeStamps=1759308464 تکراری → رد شد.
# رکورد 281: TimeStamps=1759294769 تکراری → رد شد.
# رکورد 282: TimeStamps=1759284631 تکراری → رد شد.
# رکورد 283: TimeStamps=1759265352 تکراری → رد شد.
# رکورد 284: TimeStamps=1759252800 تکراری → رد شد.
# رکورد 285: TimeStamps=1759240607 تکراری → رد شد.
# رکورد 286: TimeStamps=1759225635 تکراری → رد شد.
# رکورد 287: TimeStamps=1759211808 تکراری → رد شد.
# رکورد 288: TimeStamps=1759192881 تکراری → رد شد.
# رکورد 289: TimeStamps=1759178829 تکراری → رد شد.
# رکورد 290: TimeStamps=1759164692 تکراری → رد شد.
# رکورد 291: TimeStamps=1759150884 تکراری → رد شد.
# رکورد 292: TimeStamps=1759135420 تکراری → رد شد.
# رکورد 293: TimeStamps=1759122971 تکراری → رد شد.
# رکورد 294: TimeStamps=1759111234 تکراری → رد شد.
# رکورد 295: TimeStamps=1759095648 تکراری → رد شد.
# رکورد 296: TimeStamps=1759079230 تکراری → رد شد.
# رکورد 297: TimeStamps=1759064096 تکراری → رد شد.
# رکورد 298: TimeStamps=1759049491 تکراری → رد شد.
# رکورد 299: TimeStamps=1759035715 تکراری → رد شد.
# رکورد 300: TimeStamps=1759026158 تکراری → رد شد.
# رکورد 301: TimeStamps=1759005628 تکراری → رد شد.
# رکورد 302: TimeStamps=1758994922 تکراری → رد شد.
# رکورد 303: TimeStamps=1758979678 تکراری → رد شد.
# رکورد 304: TimeStamps=1758964788 تکراری → رد شد.
# رکورد 305: TimeStamps=1758948959 تکراری → رد شد.
# رکورد 306: TimeStamps=1758939005 تکراری → رد شد.
# رکورد 307: TimeStamps=1758919037 تکراری → رد شد.
# رکورد 308: TimeStamps=1758907850 تکراری → رد شد.
# رکورد 309: TimeStamps=1758896319 تکراری → رد شد.
# رکورد 310: TimeStamps=1758875981 تکراری → رد شد.
# رکورد 311: TimeStamps=1758866320 تکراری → رد شد.
# رکورد 312: TimeStamps=1758849616 تکراری → رد شد.
# رکورد 313: TimeStamps=1758833280 تکراری → رد شد.
# رکورد 314: TimeStamps=1758819545 تکراری → رد شد.
# رکورد 315: TimeStamps=1758808655 تکراری → رد شد.
# رکورد 316: TimeStamps=1758793797 تکراری → رد شد.
# رکورد 317: TimeStamps=1758776188 تکراری → رد شد.
# رکورد 318: TimeStamps=1758766526 تکراری → رد شد.
# رکورد 319: TimeStamps=1758746658 تکراری → رد شد.
# رکورد 320: TimeStamps=1758732812 تکراری → رد شد.
# رکورد 321: TimeStamps=1758718670 تکراری → رد شد.
# رکورد 322: TimeStamps=1758703903 تکراری → رد شد.
# رکورد 323: TimeStamps=1758690837 تکراری → رد شد.
# رکورد 324: TimeStamps=1758680609 تکراری → رد شد.
# رکورد 325: TimeStamps=1758660011 تکراری → رد شد.
# رکورد 326: TimeStamps=1758650309 تکراری → رد شد.
# رکورد 327: TimeStamps=1758631735 تکراری → رد شد.
# رکورد 328: TimeStamps=1758616983 تکراری → رد شد.
# رکورد 329: TimeStamps=1758602556 تکراری → رد شد.
# رکورد 330: TimeStamps=1758592429 تکراری → رد شد.
# رکورد 331: TimeStamps=1758573578 تکراری → رد شد.
# رکورد 332: TimeStamps=1758561685 تکراری → رد شد.
# رکورد 333: TimeStamps=1758550152 تکراری → رد شد.
# رکورد 334: TimeStamps=1758534894 تکراری → رد شد.
# رکورد 335: TimeStamps=1758518079 تکراری → رد شد.
# رکورد 336: TimeStamps=1758507246 تکراری → رد شد.
# رکورد 337: TimeStamps=1758487337 تکراری → رد شد.
# رکورد 338: TimeStamps=1758477018 تکراری → رد شد.
# رکورد 339: TimeStamps=1758461324 تکراری → رد شد.
# رکورد 340: TimeStamps=1758444413 تکراری → رد شد.
# رکورد 341: TimeStamps=1758430918 تکراری → رد شد.
# رکورد 342: TimeStamps=1758418048 تکراری → رد شد.
# رکورد 343: TimeStamps=1758401274 تکراری → رد شد.
# رکورد 344: TimeStamps=1758387713 تکراری → رد شد.
# رکورد 345: TimeStamps=1758374528 تکراری → رد شد.
# رکورد 346: TimeStamps=1758357602 تکراری → رد شد.
# رکورد 347: TimeStamps=1758346136 تکراری → رد شد.
# رکورد 348: TimeStamps=1758334557 تکراری → رد شد.
# رکورد 349: TimeStamps=1758314431 تکراری → رد شد.
# رکورد 350: TimeStamps=1758302609 تکراری → رد شد.
# رکورد 351: TimeStamps=1758290264 تکراری → رد شد.
# رکورد 352: TimeStamps=1758271549 تکراری → رد شد.
# رکورد 353: TimeStamps=1758259342 تکراری → رد شد.
# رکورد 354: TimeStamps=1758247909 تکراری → رد شد.
# رکورد 355: TimeStamps=1758227975 تکراری → رد شد.
# رکورد 356: TimeStamps=1758214577 تکراری → رد شد.
# رکورد 357: TimeStamps=1758204307 تکراری → رد شد.
# رکورد 358: TimeStamps=1758184618 تکراری → رد شد.
# رکورد 359: TimeStamps=1758174414 تکراری → رد شد.
# رکورد 360: TimeStamps=1758161548 تکراری → رد شد.
# رکورد 361: TimeStamps=1758142071 تکراری → رد شد.
# رکورد 362: TimeStamps=1758128634 تکراری → رد شد.
# رکورد 363: TimeStamps=1758116707 تکراری → رد شد.
# رکورد 364: TimeStamps=1758098058 تکراری → رد شد.
# رکورد 365: TimeStamps=1758086001 تکراری → رد شد.
# رکورد 366: TimeStamps=1758074896 تکراری → رد شد.
# رکورد 367: TimeStamps=1758056489 تکراری → رد شد.
# رکورد 368: TimeStamps=1758044740 تکراری → رد شد.
# رکورد 369: TimeStamps=1758027930 تکراری → رد شد.
# رکورد 370: TimeStamps=1758012513 تکراری → رد شد.
# رکورد 371: TimeStamps=1757999482 تکراری → رد شد.
# رکورد 372: TimeStamps=1757988016 تکراری → رد شد.
# رکورد 373: TimeStamps=1757970034 تکراری → رد شد.
# رکورد 374: TimeStamps=1757955356 تکراری → رد شد.
# رکورد 375: TimeStamps=1757943163 تکراری → رد شد.
# رکورد 376: TimeStamps=1757925951 تکراری → رد شد.
# رکورد 377: TimeStamps=1757913631 تکراری → رد شد.
# رکورد 378: TimeStamps=1757900892 تکراری → رد شد.
# رکورد 379: TimeStamps=1757883095 تکراری → رد شد.
# رکورد 380: TimeStamps=1757869561 تکراری → رد شد.
# رکورد 381: TimeStamps=1757858110 تکراری → رد شد.
# رکورد 382: TimeStamps=1757838825 تکراری → رد شد.
# رکورد 383: TimeStamps=1757827629 تکراری → رد شد.
# رکورد 384: TimeStamps=1757810534 تکراری → رد شد.
# رکورد 385: TimeStamps=1757796320 تکراری → رد شد.
# رکورد 386: TimeStamps=1757782316 تکراری → رد شد.
# رکورد 387: TimeStamps=1757770141 تکراری → رد شد.
# رکورد 388: TimeStamps=1757753124 تکراری → رد شد.
# رکورد 389: TimeStamps=1757739253 تکراری → رد شد.
# رکورد 390: TimeStamps=1757727404 تکراری → رد شد.
# رکورد 391: TimeStamps=1757709583 تکراری → رد شد.
# رکورد 392: TimeStamps=1757698895 تکراری → رد شد.
# رکورد 393: TimeStamps=1757684230 تکراری → رد شد.
# رکورد 394: TimeStamps=1757667181 تکراری → رد شد.
# رکورد 395: TimeStamps=1757654482 تکراری → رد شد.
# رکورد 396: TimeStamps=1757643288 تکراری → رد شد.
# رکورد 397: TimeStamps=1757623176 تکراری → رد شد.
# رکورد 398: TimeStamps=1757612821 تکراری → رد شد.
# رکورد 399: TimeStamps=1757596304 تکراری → رد شد.
# رکورد 400: TimeStamps=1757580796 تکراری → رد شد.
# رکورد 401: TimeStamps=1757565637 تکراری → رد شد.
# رکورد 402: TimeStamps=1757555487 تکراری → رد شد.
# رکورد 403: TimeStamps=1757536736 تکراری → رد شد.
# رکورد 404: TimeStamps=1757523618 تکراری → رد شد.
# رکورد 405: TimeStamps=1757513412 تکراری → رد شد.
# رکورد 406: TimeStamps=1757493868 تکراری → رد شد.
# رکورد 407: TimeStamps=1757483763 تکراری → رد شد.
# رکورد 408: TimeStamps=1757467593 تکراری → رد شد.
# رکورد 409: TimeStamps=1757450967 تکراری → رد شد.
# رکورد 410: TimeStamps=1757437115 تکراری → رد شد.
# رکورد 411: TimeStamps=1757424546 تکراری → رد شد.
# رکورد 412: TimeStamps=1757407411 تکراری → رد شد.
# رکورد 413: TimeStamps=1757395022 تکراری → رد شد.
# رکورد 414: TimeStamps=1757382498 تکراری → رد شد.
# رکورد 415: TimeStamps=1757364013 تکراری → رد شد.
# رکورد 416: TimeStamps=1757353455 تکراری → رد شد.
# رکورد 417: TimeStamps=1757337732 تکراری → رد شد.
# رکورد 418: TimeStamps=1757321169 تکراری → رد شد.
# رکورد 419: TimeStamps=1757308280 تکراری → رد شد.
# رکورد 420: TimeStamps=1757298232 تکراری → رد شد.
# رکورد 421: TimeStamps=1757277600 تکراری → رد شد.
# رکورد 422: TimeStamps=1757267076 تکراری → رد شد.
# رکورد 423: TimeStamps=1757250709 تکراری → رد شد.
# رکورد 424: TimeStamps=1757236260 تکراری → رد شد.
# رکورد 425: TimeStamps=1757222438 تکراری → رد شد.
# رکورد 426: TimeStamps=1757208559 تکراری → رد شد.
# رکورد 427: TimeStamps=1757191664 تکراری → رد شد.
# رکورد 428: TimeStamps=1757178047 تکراری → رد شد.
# رکورد 429: TimeStamps=1757167036 تکراری → رد شد.
# رکورد 430: TimeStamps=1757149399 تکراری → رد شد.
# رکورد 431: TimeStamps=1757135357 تکراری → رد شد.
# رکورد 432: TimeStamps=1757119459 تکراری → رد شد.
# رکورد 433: TimeStamps=1757105161 تکراری → رد شد.
# رکورد 434: TimeStamps=1757091289 تکراری → رد شد.
# رکورد 435: TimeStamps=1757079299 تکراری → رد شد.
# رکورد 436: TimeStamps=1757061547 تکراری → رد شد.
# رکورد 437: TimeStamps=1757048339 تکراری → رد شد.
# رکورد 438: TimeStamps=1757038457 تکراری → رد شد.
# رکورد 439: TimeStamps=1757018904 تکراری → رد شد.
# رکورد 440: TimeStamps=1757007321 تکراری → رد شد.
# رکورد 441: TimeStamps=1756991861 تکراری → رد شد.
# رکورد 442: TimeStamps=1756975983 تکراری → رد شد.
# رکورد 443: TimeStamps=1756962191 تکراری → رد شد.
# رکورد 444: TimeStamps=1756952430 تکراری → رد شد.
# رکورد 445: TimeStamps=1756932087 تکراری → رد شد.
# رکورد 446: TimeStamps=1756921212 تکراری → رد شد.
# رکورد 447: TimeStamps=1756907800 تکراری → رد شد.
# رکورد 448: TimeStamps=1756889069 تکراری → رد شد.
# رکورد 449: TimeStamps=1756875390 تکراری → رد شد.
# رکورد 450: TimeStamps=1756862338 تکراری → رد شد.
# رکورد 451: TimeStamps=1756846056 تکراری → رد شد.
# رکورد 452: TimeStamps=1756832551 تکراری → رد شد.
# رکورد 453: TimeStamps=1756821704 تکراری → رد شد.
# رکورد 454: TimeStamps=1756803340 تکراری → رد شد.
# رکورد 455: TimeStamps=1756791551 تکراری → رد شد.
# رکورد 456: TimeStamps=1756776299 تکراری → رد شد.
# رکورد 457: TimeStamps=1756760657 تکراری → رد شد.
# رکورد 458: TimeStamps=1756746152 تکراری → رد شد.
# رکورد 459: TimeStamps=1756730618 تکراری → رد شد.
# رکورد 460: TimeStamps=1756715615 تکراری → رد شد.
# رکورد 461: TimeStamps=1756703497 تکراری → رد شد.
# رکورد 462: TimeStamps=1756692928 تکراری → رد شد.
# رکورد 463: TimeStamps=1756673538 تکراری → رد شد.
# رکورد 464: TimeStamps=1756660979 تکراری → رد شد.
# رکورد 465: TimeStamps=1756646582 تکراری → رد شد.
# رکورد 466: TimeStamps=1756629890 تکراری → رد شد.
# رکورد 467: TimeStamps=1756615755 تکراری → رد شد.
# رکورد 468: TimeStamps=1756607140 تکراری → رد شد.
# رکورد 469: TimeStamps=1756586350 تکراری → رد شد.
# رکورد 470: TimeStamps=1756576605 تکراری → رد شد.
# رکورد 471: TimeStamps=1756562296 تکراری → رد شد.
# رکورد 472: TimeStamps=1756544371 تکراری → رد شد.
# رکورد 473: TimeStamps=1756531650 تکراری → رد شد.
# رکورد 474: TimeStamps=1756519028 تکراری → رد شد.
# رکورد 475: TimeStamps=1756500125 تکراری → رد شد.
# رکورد 476: TimeStamps=1756486756 تکراری → رد شد.
# رکورد 477: TimeStamps=1756472760 تکراری → رد شد.
# رکورد 478: TimeStamps=1756457184 تکراری → رد شد.
# رکورد 479: TimeStamps=1756443863 تکراری → رد شد.
# رکورد 480: TimeStamps=1756428123 تکراری → رد شد.
# رکورد 481: TimeStamps=1756414150 تکراری → رد شد.
# رکورد 482: TimeStamps=1756400181 تکراری → رد شد.
# رکورد 483: TimeStamps=1756388106 تکراری → رد شد.
# رکورد 484: TimeStamps=1756370727 تکراری → رد شد.
# رکورد 485: TimeStamps=1756357236 تکراری → رد شد.
# رکورد 486: TimeStamps=1756347256 تکراری → رد شد.
# رکورد 487: TimeStamps=1756327390 تکراری → رد شد.
# رکورد 488: TimeStamps=1756313188 تکراری → رد شد.
# رکورد 489: TimeStamps=1756298716 تکراری → رد شد.
# رکورد 490: TimeStamps=1756285192 تکراری → رد شد.
# رکورد 491: TimeStamps=1756271446 تکراری → رد شد.
# رکورد 492: TimeStamps=1756256042 تکراری → رد شد.
# رکورد 493: TimeStamps=1755938829 تکراری → رد شد.
# رکورد 494: TimeStamps=1755926264 تکراری → رد شد.
# رکورد 495: TimeStamps=1755915677 تکراری → رد شد.
# رکورد 496: TimeStamps=1755895296 تکراری → رد شد.
# رکورد 497: TimeStamps=1755882589 تکراری → رد شد.
# رکورد 498: TimeStamps=1755871442 تکراری → رد شد.
# رکورد 499: TimeStamps=1755854536 تکراری → رد شد.
# رکورد 500: TimeStamps=1755839974 تکراری → رد شد.
# رکورد 501: TimeStamps=1755827829 تکراری → رد شد.
# رکورد 502: TimeStamps=1755808839 تکراری → رد شد.
# رکورد 503: TimeStamps=1755795463 تکراری → رد شد.
# رکورد 504: TimeStamps=1755784452 تکراری → رد شد.
# رکورد 505: TimeStamps=1755765741 تکراری → رد شد.
# رکورد 506: TimeStamps=1755755318 تکراری → رد شد.
# رکورد 507: TimeStamps=1755737031 تکراری → رد شد.
# رکورد 508: TimeStamps=1755722685 تکراری → رد شد.
# رکورد 509: TimeStamps=1755709732 تکراری → رد شد.
# رکورد 510: TimeStamps=1755697456 تکراری → رد شد.
# رکورد 511: TimeStamps=1755679966 تکراری → رد شد.
# رکورد 512: TimeStamps=1755667517 تکراری → رد شد.
# رکورد 513: TimeStamps=1755656103 تکراری → رد شد.
# رکورد 514: TimeStamps=1755636194 تکراری → رد شد.
# رکورد 515: TimeStamps=1755623294 تکراری → رد شد.
# رکورد 516: TimeStamps=1755609434 تکراری → رد شد.
# رکورد 517: TimeStamps=1755593534 تکراری → رد شد.
# رکورد 518: TimeStamps=1755581039 تکراری → رد شد.
# رکورد 519: TimeStamps=1755570193 تکراری → رد شد.
# رکورد 520: TimeStamps=1755549752 تکراری → رد شد.
# رکورد 521: TimeStamps=1755539637 تکراری → رد شد.
# رکورد 522: TimeStamps=1755526211 تکراری → رد شد.
# رکورد 523: TimeStamps=1755506892 تکراری → رد شد.
# رکورد 524: TimeStamps=1755494212 تکراری → رد شد.
# رکورد 525: TimeStamps=1755483391 تکراری → رد شد.
# رکورد 526: TimeStamps=1755463324 تکراری → رد شد.
# رکورد 527: TimeStamps=1755451812 تکراری → رد شد.
# رکورد 528: TimeStamps=1755437168 تکراری → رد شد.
# رکورد 529: TimeStamps=1755421406 تکراری → رد شد.
# رکورد 530: TimeStamps=1755407956 تکراری → رد شد.
# رکورد 531: TimeStamps=1755394371 تکراری → رد شد.
# رکورد 532: TimeStamps=1755377333 تکراری → رد شد.
# رکورد 533: TimeStamps=1755363885 تکراری → رد شد.
# رکورد 534: TimeStamps=1755350759 تکراری → رد شد.
# رکورد 535: TimeStamps=1755333153 تکراری → رد شد.
# رکورد 536: TimeStamps=1755321414 تکراری → رد شد.
# رکورد 537: TimeStamps=1755310395 تکراری → رد شد.
# رکورد 538: TimeStamps=1755290882 تکراری → رد شد.
# رکورد 539: TimeStamps=1755277680 تکراری → رد شد.
# رکورد 540: TimeStamps=1755263063 تکراری → رد شد.
# رکورد 541: TimeStamps=1755247686 تکراری → رد شد.
# رکورد 542: TimeStamps=1755234498 تکراری → رد شد.
# رکورد 543: TimeStamps=1755223983 تکراری → رد شد.
# رکورد 544: TimeStamps=1755204184 تکراری → رد شد.
# رکورد 545: TimeStamps=1755192959 تکراری → رد شد.
# رکورد 546: TimeStamps=1755175204 تکراری → رد شد.
# رکورد 547: TimeStamps=1755161292 تکراری → رد شد.
# رکورد 548: TimeStamps=1755148297 تکراری → رد شد.
# رکورد 549: TimeStamps=1755133031 تکراری → رد شد.
# رکورد 550: TimeStamps=1755118035 تکراری → رد شد.
# رکورد 551: TimeStamps=1755104276 تکراری → رد شد.
# رکورد 552: TimeStamps=1755093928 تکراری → رد شد.
# رکورد 553: TimeStamps=1755074699 تکراری → رد شد.
# رکورد 554: TimeStamps=1755063605 تکراری → رد شد.
# رکورد 555: TimeStamps=1755045866 تکراری → رد شد.
# رکورد 556: TimeStamps=1755031613 تکراری → رد شد.
# رکورد 557: TimeStamps=1755017767 تکراری → رد شد.
# رکورد 558: TimeStamps=1755006217 تکراری → رد شد.
# رکورد 559: TimeStamps=1754988977 تکراری → رد شد.
# رکورد 560: TimeStamps=1754976308 تکراری → رد شد.
# رکورد 561: TimeStamps=1754965219 تکراری → رد شد.
# رکورد 562: TimeStamps=1754945033 تکراری → رد شد.
# رکورد 563: TimeStamps=1754931285 تکراری → رد شد.
# رکورد 564: TimeStamps=1754916905 تکراری → رد شد.
# رکورد 565: TimeStamps=1754902592 تکراری → رد شد.
# رکورد 566: TimeStamps=1754889844 تکراری → رد شد.
# رکورد 567: TimeStamps=1754878484 تکراری → رد شد.
# رکورد 568: TimeStamps=1754858333 تکراری → رد شد.
# رکورد 569: TimeStamps=1754844221 تکراری → رد شد.
# رکورد 570: TimeStamps=1754834171 تکراری → رد شد.
# رکورد 571: TimeStamps=1754815624 تکراری → رد شد.
# رکورد 572: TimeStamps=1754803121 تکراری → رد شد.
# رکورد 573: TimeStamps=1754790012 تکراری → رد شد.
# رکورد 574: TimeStamps=1754772127 تکراری → رد شد.
# رکورد 575: TimeStamps=1754760422 تکراری → رد شد.
# رکورد 576: TimeStamps=1754746005 تکراری → رد شد.
# رکورد 577: TimeStamps=1754729061 تکراری → رد شد.
# رکورد 578: TimeStamps=1754716994 تکراری → رد شد.
# رکورد 579: TimeStamps=1754702974 تکراری → رد شد.
# رکورد 580: TimeStamps=1754686266 تکراری → رد شد.
# رکورد 581: TimeStamps=1754672955 تکراری → رد شد.
# رکورد 582: TimeStamps=1754661125 تکراری → رد شد.
# رکورد 583: TimeStamps=1754642033 تکراری → رد شد.
# رکورد 584: TimeStamps=1754630649 تکراری → رد شد.
# رکورد 585: TimeStamps=1754618778 تکراری → رد شد.
# رکورد 586: TimeStamps=1754599462 تکراری → رد شد.
# رکورد 587: TimeStamps=1754586483 تکراری → رد شد.
# رکورد 588: TimeStamps=1754572654 تکراری → رد شد.
# رکورد 589: TimeStamps=1754555639 تکراری → رد شد.
# رکورد 590: TimeStamps=1754542663 تکراری → رد شد.
# رکورد 591: TimeStamps=1754533132 تکراری → رد شد.
# رکورد 592: TimeStamps=1754512791 تکراری → رد شد.
# رکورد 593: TimeStamps=1754501711 تکراری → رد شد.
# رکورد 594: TimeStamps=1754485173 تکراری → رد شد.
# رکورد 595: TimeStamps=1754470537 تکراری → رد شد.
# رکورد 596: TimeStamps=1754457148 تکراری → رد شد.
# رکورد 597: TimeStamps=1754445461 تکراری → رد شد.
# رکورد 598: TimeStamps=1754427418 تکراری → رد شد.
# رکورد 599: TimeStamps=1754413492 تکراری → رد شد.
# رکورد 600: TimeStamps=1754402652 تکراری → رد شد.
# رکورد 601: TimeStamps=1754383523 تکراری → رد شد.
# رکورد 602: TimeStamps=1754371778 تکراری → رد شد.
# رکورد 603: TimeStamps=1754354680 تکراری → رد شد.
# رکورد 604: TimeStamps=1754340244 تکراری → رد شد.
# رکورد 605: TimeStamps=1754326352 تکراری → رد شد.
# رکورد 606: TimeStamps=1754313470 تکراری → رد شد.
# رکورد 607: TimeStamps=1754297055 تکراری → رد شد.
# رکورد 608: TimeStamps=1754284390 تکراری → رد شد.
# رکورد 609: TimeStamps=1754273165 تکراری → رد شد.
# رکورد 610: TimeStamps=1754253770 تکراری → رد شد.
# رکورد 611: TimeStamps=1754240566 تکراری → رد شد.
# رکورد 612: TimeStamps=1754226692 تکراری → رد شد.
# رکورد 613: TimeStamps=1754211139 تکراری → رد شد.
# رکورد 614: TimeStamps=1754196838 تکراری → رد شد.
# رکورد 615: TimeStamps=1754187423 تکراری → رد شد.
# رکورد 616: TimeStamps=1754167312 تکراری → رد شد.
# رکورد 617: TimeStamps=1754158135 تکراری → رد شد.
# رکورد 618: TimeStamps=1754139631 تکراری → رد شد.
# رکورد 619: TimeStamps=1754124809 تکراری → رد شد.
# رکورد 620: TimeStamps=1754110065 تکراری → رد شد.
# رکورد 621: TimeStamps=1754101252 تکراری → رد شد.
# رکورد 622: TimeStamps=1754080827 تکراری → رد شد.
# رکورد 623: TimeStamps=1754067551 تکراری → رد شد.
# رکورد 624: TimeStamps=1754057748 تکراری → رد شد.
# رکورد 625: TimeStamps=1754037804 تکراری → رد شد.
# رکورد 626: TimeStamps=1754024149 تکراری → رد شد.
# رکورد 627: TimeStamps=1754011826 تکراری → رد شد.
# رکورد 628: TimeStamps=1753994895 تکراری → رد شد.
# رکورد 629: TimeStamps=1753981382 تکراری → رد شد.
# رکورد 630: TimeStamps=1753966773 تکراری → رد شد.
# رکورد 631: TimeStamps=1753950855 تکراری → رد شد.
# رکورد 632: TimeStamps=1753938620 تکراری → رد شد.
# رکورد 633: TimeStamps=1753927765 تکراری → رد شد.
# رکورد 634: TimeStamps=1753908249 تکراری → رد شد.
# رکورد 635: TimeStamps=1753896917 تکراری → رد شد.
# رکورد 636: TimeStamps=1753880495 تکراری → رد شد.
# رکورد 637: TimeStamps=1753864966 تکراری → رد شد.
# رکورد 638: TimeStamps=1753851976 تکراری → رد شد.
# رکورد 639: TimeStamps=1753841286 تکراری → رد شد.
# رکورد 640: TimeStamps=1753821770 تکراری → رد شد.
# رکورد 641: TimeStamps=1753810718 تکراری → رد شد.
# رکورد 642: TimeStamps=1753795089 تکراری → رد شد.
# رکورد 643: TimeStamps=1753779089 تکراری → رد شد.
# رکورد 644: TimeStamps=1753767274 تکراری → رد شد.
# رکورد 645: TimeStamps=1753754268 تکراری → رد شد.
# رکورد 646: TimeStamps=1753735646 تکراری → رد شد.
# رکورد 647: TimeStamps=1753722320 تکراری → رد شد.
# رکورد 648: TimeStamps=1753710893 تکراری → رد شد.
# رکورد 649: TimeStamps=1753692048 تکراری → رد شد.
# رکورد 650: TimeStamps=1753680330 تکراری → رد شد.
# رکورد 651: TimeStamps=1753663361 تکراری → رد شد.
# رکورد 652: TimeStamps=1753649163 تکراری → رد شد.
# رکورد 653: TimeStamps=1753635117 تکراری → رد شد.
# رکورد 654: TimeStamps=1753624223 تکراری → رد شد.
# رکورد 655: TimeStamps=1753606266 تکراری → رد شد.
# رکورد 656: TimeStamps=1753592054 تکراری → رد شد.
# رکورد 657: TimeStamps=1753582266 تکراری → رد شد.
# رکورد 658: TimeStamps=1753562659 تکراری → رد شد.
# رکورد 659: TimeStamps=1753548390 تکراری → رد شد.
# رکورد 660: TimeStamps=1753535910 تکراری → رد شد.
# رکورد 661: TimeStamps=1753520841 تکراری → رد شد.
# رکورد 662: TimeStamps=1753505542 تکراری → رد شد.
# رکورد 663: TimeStamps=1753494970 تکراری → رد شد.
# رکورد 664: TimeStamps=1753476028 تکراری → رد شد.
# رکورد 665: TimeStamps=1753467457 تکراری → رد شد.
# رکورد 666: TimeStamps=1753451796 تکراری → رد شد.
# رکورد 667: TimeStamps=1753432757 تکراری → رد شد.
# رکورد 668: TimeStamps=1753420078 تکراری → رد شد.
# رکورد 669: TimeStamps=1753409680 تکراری → رد شد.
# رکورد 670: TimeStamps=1753389948 تکراری → رد شد.
# رکورد 671: TimeStamps=1753375224 تکراری → رد شد.
# رکورد 672: TimeStamps=1753365897 تکراری → رد شد.
# رکورد 673: TimeStamps=1753346682 تکراری → رد شد.
# رکورد 674: TimeStamps=1753333958 تکراری → رد شد.
# رکورد 675: TimeStamps=1753320476 تکراری → رد شد.
# رکورد 676: TimeStamps=1753303792 تکراری → رد شد.
# رکورد 677: TimeStamps=1753290258 تکراری → رد شد.
# رکورد 678: TimeStamps=1753278703 تکراری → رد شد.
# رکورد 679: TimeStamps=1753261998 تکراری → رد شد.
# رکورد 680: TimeStamps=1753246606 تکراری → رد شد.
# رکورد 681: TimeStamps=1753236092 تکراری → رد شد.
# رکورد 682: TimeStamps=1753217524 تکراری → رد شد.
# رکورد 683: TimeStamps=1753203729 تکراری → رد شد.
# رکورد 684: TimeStamps=1753189661 تکراری → رد شد.
# رکورد 685: TimeStamps=1753174046 تکراری → رد شد.
# رکورد 686: TimeStamps=1753160709 تکراری → رد شد.
# رکورد 687: TimeStamps=1753146528 تکراری → رد شد.
# رکورد 688: TimeStamps=1753130489 تکراری → رد شد.
# رکورد 689: TimeStamps=1753119622 تکراری → رد شد.
# رکورد 690: TimeStamps=1753106850 تکراری → رد شد.
# رکورد 691: TimeStamps=1753089660 تکراری → رد شد.
# رکورد 692: TimeStamps=1753073817 تکراری → رد شد.
# رکورد 693: TimeStamps=1753064120 تکراری → رد شد.
# رکورد 694: TimeStamps=1753044180 تکراری → رد شد.
# رکورد 695: TimeStamps=1753030664 تکراری → رد شد.
# رکورد 696: TimeStamps=1753019133 تکراری → رد شد.
# رکورد 697: TimeStamps=1753000361 تکراری → رد شد.
# رکورد 698: TimeStamps=1752989548 تکراری → رد شد.
# رکورد 699: TimeStamps=1752972219 تکراری → رد شد.
# رکورد 700: TimeStamps=1752958021 تکراری → رد شد.
# رکورد 701: TimeStamps=1752943796 تکراری → رد شد.
# رکورد 702: TimeStamps=1752931663 تکراری → رد شد.
# رکورد 703: TimeStamps=1752914952 تکراری → رد شد.
# رکورد 704: TimeStamps=1752901155 تکراری → رد شد.
# رکورد 705: TimeStamps=1752891264 تکراری → رد شد.
# رکورد 706: TimeStamps=1752871338 تکراری → رد شد.
# رکورد 707: TimeStamps=1752857267 تکراری → رد شد.
# رکورد 708: TimeStamps=1752844852 تکراری → رد شد.
# رکورد 709: TimeStamps=1752828850 تکراری → رد شد.
# رکورد 710: TimeStamps=1752815303 تکراری → رد شد.
# رکورد 711: TimeStamps=1752804873 تکراری → رد شد.
# رکورد 712: TimeStamps=1752784763 تکراری → رد شد.
# رکورد 713: TimeStamps=1752776501 تکراری → رد شد.
# رکورد 714: TimeStamps=1752760317 تکراری → رد شد.
# رکورد 715: TimeStamps=1752743841 تکراری → رد شد.
# رکورد 716: TimeStamps=1752728649 تکراری → رد شد.
# رکورد 717: TimeStamps=1752717577 تکراری → رد شد.
# رکورد 718: TimeStamps=1752698387 تکراری → رد شد.
# رکورد 719: TimeStamps=1752687859 تکراری → رد شد.
# رکورد 720: TimeStamps=1752670575 تکراری → رد شد.
# رکورد 721: TimeStamps=1752655606 تکراری → رد شد.
# رکورد 722: TimeStamps=1752644884 تکراری → رد شد.
# رکورد 723: TimeStamps=1752629153 تکراری → رد شد.
# رکورد 724: TimeStamps=1752612501 تکراری → رد شد.
# رکورد 725: TimeStamps=1752598978 تکراری → رد شد.
# رکورد 726: TimeStamps=1752587133 تکراری → رد شد.
# رکورد 727: TimeStamps=1752569654 تکراری → رد شد.
# رکورد 728: TimeStamps=1752556129 تکراری → رد شد.
# رکورد 729: TimeStamps=1752545164 تکراری → رد شد.
# رکورد 730: TimeStamps=1752525846 تکراری → رد شد.
# رکورد 731: TimeStamps=1752513221 تکراری → رد شد.
# رکورد 732: TimeStamps=1752498765 تکراری → رد شد.
# رکورد 733: TimeStamps=1752482961 تکراری → رد شد.
# رکورد 734: TimeStamps=1752469538 تکراری → رد شد.
# رکورد 735: TimeStamps=1752458743 تکراری → رد شد.
# رکورد 736: TimeStamps=1752439287 تکراری → رد شد.
# رکورد 737: TimeStamps=1752428154 تکراری → رد شد.
# رکورد 738: TimeStamps=1752415127 تکراری → رد شد.
# رکورد 739: TimeStamps=1752398005 تکراری → رد شد.
# رکورد 740: TimeStamps=1752383008 تکراری → رد شد.
# رکورد 741: TimeStamps=1752372203 تکراری → رد شد.
# رکورد 742: TimeStamps=1752352926 تکراری → رد شد.
# رکورد 743: TimeStamps=1752338990 تکراری → رد شد.
# رکورد 744: TimeStamps=1752329220 تکراری → رد شد.
# رکورد 745: TimeStamps=1752309912 تکراری → رد شد.
# رکورد 746: TimeStamps=1752298452 تکراری → رد شد.
# رکورد 747: TimeStamps=1752281029 تکراری → رد شد.
# رکورد 748: TimeStamps=1752266818 تکراری → رد شد.
# رکورد 749: TimeStamps=1752252879 تکراری → رد شد.
# رکورد 750: TimeStamps=1752237613 تکراری → رد شد.
# رکورد 751: TimeStamps=1752223306 تکراری → رد شد.
# رکورد 752: TimeStamps=1752210606 تکراری → رد شد.
# رکورد 753: TimeStamps=1752199823 تکراری → رد شد.
# رکورد 754: TimeStamps=1752179940 تکراری → رد شد.
# رکورد 755: TimeStamps=1752168296 تکراری → رد شد.
# رکورد 756: TimeStamps=1752153052 تکراری → رد شد.
# رکورد 757: TimeStamps=1752137452 تکراری → رد شد.
# رکورد 758: TimeStamps=1752123139 تکراری → رد شد.
# رکورد 759: TimeStamps=1752113968 تکراری → رد شد.
# رکورد 760: TimeStamps=1752093600 تکراری → رد شد.
# رکورد 761: TimeStamps=1752082526 تکراری → رد شد.
# رکورد 762: TimeStamps=1752069607 تکراری → رد شد.
# رکورد 763: TimeStamps=1752050206 تکراری → رد شد.
# رکورد 764: TimeStamps=1752036765 تکراری → رد شد.
# رکورد 765: TimeStamps=1752026942 تکراری → رد شد.
# رکورد 766: TimeStamps=1752007579 تکراری → رد شد.
# رکورد 767: TimeStamps=1751994617 تکراری → رد شد.
# رکورد 768: TimeStamps=1751983302 تکراری → رد شد.
# رکورد 769: TimeStamps=1751964968 تکراری → رد شد.
# رکورد 770: TimeStamps=1751953562 تکراری → رد شد.
# رکورد 771: TimeStamps=1751937485 تکراری → رد شد.
# رکورد 772: TimeStamps=1751921174 تکراری → رد شد.
# رکورد 773: TimeStamps=1751907830 تکراری → رد شد.
# رکورد 774: TimeStamps=1751891876 تکراری → رد شد.
# رکورد 775: TimeStamps=1751878422 تکراری → رد شد.
# رکورد 776: TimeStamps=1751863429 تکراری → رد شد.
# رکورد 777: TimeStamps=1751853541 تکراری → رد شد.
# رکورد 778: TimeStamps=1751834706 تکراری → رد شد.
# رکورد 779: TimeStamps=1751820993 تکراری → رد شد.
# رکورد 780: TimeStamps=1751806766 تکراری → رد شد.
# رکورد 781: TimeStamps=1751792964 تکراری → رد شد.
# رکورد 782: TimeStamps=1751778621 تکراری → رد شد.
# رکورد 783: TimeStamps=1751767348 تکراری → رد شد.
# رکورد 784: TimeStamps=1751748181 تکراری → رد شد.
# رکورد 785: TimeStamps=1751734135 تکراری → رد شد.
# رکورد 786: TimeStamps=1751724336 تکراری → رد شد.
# رکورد 787: TimeStamps=1751706772 تکراری → رد شد.
# رکورد 788: TimeStamps=1751691433 تکراری → رد شد.
# رکورد 789: TimeStamps=1751680179 تکراری → رد شد.
# رکورد 790: TimeStamps=1751661845 تکراری → رد شد.
# رکورد 791: TimeStamps=1751647681 تکراری → رد شد.
# رکورد 792: TimeStamps=1751637794 تکراری → رد شد.
# رکورد 793: TimeStamps=1751618047 تکراری → رد شد.
# رکورد 794: TimeStamps=1751607033 تکراری → رد شد.
# رکورد 795: TimeStamps=1751589978 تکراری → رد شد.
# رکورد 796: TimeStamps=1751575898 تکراری → رد شد.
# رکورد 797: TimeStamps=1751561756 تکراری → رد شد.
# رکورد 798: TimeStamps=1751546469 تکراری → رد شد.
# رکورد 799: TimeStamps=1751532605 تکراری → رد شد.
# رکورد 800: TimeStamps=1751520781 تکراری → رد شد.
# رکورد 801: TimeStamps=1751508472 تکراری → رد شد.
# رکورد 802: TimeStamps=1751488802 تکراری → رد شد.
# رکورد 803: TimeStamps=1751475676 تکراری → رد شد.
# رکورد 804: TimeStamps=1751461835 تکراری → رد شد.
# رکورد 805: TimeStamps=1751446589 تکراری → رد شد.
# رکورد 806: TimeStamps=1751432211 تکراری → رد شد.
# رکورد 807: TimeStamps=1751421820 تکراری → رد شد.
# رکورد 808: TimeStamps=1751402693 تکراری → رد شد.
# رکورد 809: TimeStamps=1751393654 تکراری → رد شد.
# رکورد 810: TimeStamps=1751378713 تکراری → رد شد.
# رکورد 811: TimeStamps=1751359658 تکراری → رد شد.
# رکورد 812: TimeStamps=1751344942 تکراری → رد شد.
# رکورد 813: TimeStamps=1751334940 تکراری → رد شد.
# رکورد 814: TimeStamps=1751316287 تکراری → رد شد.
# رکورد 815: TimeStamps=1751304521 تکراری → رد شد.
# رکورد 816: TimeStamps=1751288756 تکراری → رد شد.
# رکورد 817: TimeStamps=1751272720 تکراری → رد شد.
# رکورد 818: TimeStamps=1751261512 تکراری → رد شد.
# رکورد 819: TimeStamps=1751246329 تکراری → رد شد.
# رکورد 820: TimeStamps=1751230288 تکراری → رد شد.
# رکورد 821: TimeStamps=1751216785 تکراری → رد شد.
# رکورد 822: TimeStamps=1751173681 تکراری → رد شد.
# رکورد 823: TimeStamps=1751162429 تکراری → رد شد.
# رکورد 824: TimeStamps=1751143538 تکراری → رد شد.
# رکورد 825: TimeStamps=1751130939 تکراری → رد شد.
# رکورد 826: TimeStamps=1751116007 تکراری → رد شد.
# رکورد 827: TimeStamps=1751100489 تکراری → رد شد.
# رکورد 828: TimeStamps=1751087477 تکراری → رد شد.
# رکورد 829: TimeStamps=1751077084 تکراری → رد شد.
# رکورد 830: TimeStamps=1751056938 تکراری → رد شد.
# رکورد 831: TimeStamps=1751046581 تکراری → رد شد.
# رکورد 832: TimeStamps=1751033297 تکراری → رد شد.
# رکورد 833: TimeStamps=1751015742 تکراری → رد شد.
# رکورد 834: TimeStamps=1751001024 تکراری → رد شد.
# رکورد 835: TimeStamps=1750985361 تکراری → رد شد.
# رکورد 836: TimeStamps=1750970525 تکراری → رد شد.
# رکورد 837: TimeStamps=1750957880 تکراری → رد شد.
# رکورد 838: TimeStamps=1750947135 تکراری → رد شد.
# رکورد 839: TimeStamps=1750927380 تکراری → رد شد.
# رکورد 840: TimeStamps=1750916509 تکراری → رد شد.
# رکورد 841: TimeStamps=1750898647 تکراری → رد شد.
# رکورد 842: TimeStamps=1750884425 تکراری → رد شد.
# رکورد 843: TimeStamps=1750870438 تکراری → رد شد.
# رکورد 844: TimeStamps=1750859087 تکراری → رد شد.
# رکورد 845: TimeStamps=1750840994 تکراری → رد شد.
# رکورد 846: TimeStamps=1750828193 تکراری → رد شد.
# رکورد 847: TimeStamps=1750816982 تکراری → رد شد.
# رکورد 848: TimeStamps=1750797570 تکراری → رد شد.
# رکورد 849: TimeStamps=1750783117 تکراری → رد شد.
# رکورد 850: TimeStamps=1750770120 تکراری → رد شد.
# رکورد 851: TimeStamps=1750755530 تکراری → رد شد.
# رکورد 852: TimeStamps=1750740843 تکراری → رد شد.
# رکورد 853: TimeStamps=1750730656 تکراری → رد شد.
# رکورد 854: TimeStamps=1750711316 تکراری → رد شد.
# رکورد 855: TimeStamps=1750702956 تکراری → رد شد.
# رکورد 856: TimeStamps=1750686179 تکراری → رد شد.
# رکورد 857: TimeStamps=1750670038 تکراری → رد شد.
# رکورد 858: TimeStamps=1750654625 تکراری → رد شد.
# رکورد 859: TimeStamps=1750644254 تکراری → رد شد.
# رکورد 860: TimeStamps=1750625019 تکراری → رد شد.
# رکورد 861: TimeStamps=1750610934 تکراری → رد شد.
# رکورد 862: TimeStamps=1750601002 تکراری → رد شد.
# رکورد 863: TimeStamps=1750583676 تکراری → رد شد.
# رکورد 864: TimeStamps=1750571852 تکراری → رد شد.
# رکورد 865: TimeStamps=1750555425 تکراری → رد شد.
# رکورد 866: TimeStamps=1750538906 تکراری → رد شد.
# رکورد 867: TimeStamps=1750525337 تکراری → رد شد.
# رکورد 868: TimeStamps=1750514121 تکراری → رد شد.
# رکورد 869: TimeStamps=1750495992 تکراری → رد شد.
# رکورد 870: TimeStamps=1750482636 تکراری → رد شد.
# رکورد 871: TimeStamps=1750424372 تکراری → رد شد.
# رکورد 872: TimeStamps=1750409168 تکراری → رد شد.
# رکورد 873: TimeStamps=1750396597 تکراری → رد شد.
# رکورد 874: TimeStamps=1750365640 تکراری → رد شد.
# رکورد 875: TimeStamps=1750354136 تکراری → رد شد.
# رکورد 876: TimeStamps=1750298455 تکراری → رد شد.
# رکورد 877: TimeStamps=1750279459 تکراری → رد شد.
# رکورد 878: TimeStamps=1750266854 تکراری → رد شد.
# رکورد 879: TimeStamps=1750252826 تکراری → رد شد.
# رکورد 880: TimeStamps=1750240108 تکراری → رد شد.
# رکورد 881: TimeStamps=1750224981 تکراری → رد شد.
# رکورد 882: TimeStamps=1750207429 تکراری → رد شد.
# رکورد 883: TimeStamps=1750193504 تکراری → رد شد.
# رکورد 884: TimeStamps=1750179473 تکراری → رد شد.
# رکورد 885: TimeStamps=1750164935 تکراری → رد شد.
# رکورد 886: TimeStamps=1750149967 تکراری → رد شد.
# رکورد 887: TimeStamps=1750136936 تکراری → رد شد.
# رکورد 888: TimeStamps=1750079466 تکراری → رد شد.
# رکورد 889: TimeStamps=1750064259 تکراری → رد شد.
# رکورد 890: TimeStamps=1750050086 تکراری → رد شد.
# رکورد 891: TimeStamps=1750034375 تکراری → رد شد.
# رکورد 892: TimeStamps=1750022077 تکراری → رد شد.
# رکورد 893: TimeStamps=1750009966 تکراری → رد شد.
# رکورد 894: TimeStamps=1749997031 تکراری → رد شد.
# رکورد 895: TimeStamps=1749964099 تکراری → رد شد.
# رکورد 896: TimeStamps=1749953270 تکراری → رد شد.
# رکورد 897: TimeStamps=1749933849 تکراری → رد شد.
# رکورد 898: TimeStamps=1749920373 تکراری → رد شد.
# رکورد 899: TimeStamps=1749908902 تکراری → رد شد.
# رکورد 900: TimeStamps=1749890835 تکراری → رد شد.
# رکورد 901: TimeStamps=1749879492 تکراری → رد شد.
# رکورد 902: TimeStamps=1749863622 تکراری → رد شد.
# رکورد 903: TimeStamps=1749847642 تکراری → رد شد.
# رکورد 904: TimeStamps=1749834203 تکراری → رد شد.
# رکورد 905: TimeStamps=1749818519 تکراری → رد شد.
# رکورد 906: TimeStamps=1749803908 تکراری → رد شد.
# رکورد 907: TimeStamps=1749791713 تکراری → رد شد.
# رکورد 908: TimeStamps=1749779611 تکراری → رد شد.
# رکورد 909: TimeStamps=1749762078 تکراری → رد شد.
# رکورد 910: TimeStamps=1749747979 تکراری → رد شد.
# رکورد 911: TimeStamps=1749732383 تکراری → رد شد.
# رکورد 912: TimeStamps=1749718094 تکراری → رد شد.
# رکورد 913: TimeStamps=1749705094 تکراری → رد شد.
# رکورد 914: TimeStamps=1749694965 تکراری → رد شد.
# رکورد 915: TimeStamps=1749674413 تکراری → رد شد.
# رکورد 916: TimeStamps=1749664469 تکراری → رد شد.
# رکورد 917: TimeStamps=1749650538 تکراری → رد شد.
# رکورد 918: TimeStamps=1749633718 تکراری → رد شد.
# رکورد 919: TimeStamps=1749617749 تکراری → رد شد.
# رکورد 920: TimeStamps=1749607695 تکراری → رد شد.
# رکورد 921: TimeStamps=1749588300 تکراری → رد شد.
# رکورد 922: TimeStamps=1749574246 تکراری → رد شد.
# رکورد 923: TimeStamps=1749564068 تکراری → رد شد.
# رکورد 924: TimeStamps=1749545782 تکراری → رد شد.
# رکورد 925: TimeStamps=1749531696 تکراری → رد شد.
# رکورد 926: TimeStamps=1749516095 تکراری → رد شد.
# رکورد 927: TimeStamps=1749502077 تکراری → رد شد.
# رکورد 928: TimeStamps=1749488449 تکراری → رد شد.
# رکورد 929: TimeStamps=1749476451 تکراری → رد شد.
# رکورد 930: TimeStamps=1749458337 تکراری → رد شد.
# رکورد 931: TimeStamps=1749445352 تکراری → رد شد.
# رکورد 932: TimeStamps=1749434725 تکراری → رد شد.
# رکورد 933: TimeStamps=1749415428 تکراری → رد شد.
# رکورد 934: TimeStamps=1749400534 تکراری → رد شد.
# رکورد 935: TimeStamps=1749387970 تکراری → رد شد.
# رکورد 936: TimeStamps=1749372357 تکراری → رد شد.
# رکورد 937: TimeStamps=1749358478 تکراری → رد شد.
# رکورد 938: TimeStamps=1749349132 تکراری → رد شد.
# رکورد 939: TimeStamps=1749328874 تکراری → رد شد.
# رکورد 940: TimeStamps=1749317272 تکراری → رد شد.
# رکورد 941: TimeStamps=1749304664 تکراری → رد شد.
# رکورد 942: TimeStamps=1749285454 تکراری → رد شد.
# رکورد 943: TimeStamps=1749271317 تکراری → رد شد.
# رکورد 944: TimeStamps=1749261698 تکراری → رد شد.
# رکورد 945: TimeStamps=1749242725 تکراری → رد شد.
# رکورد 946: TimeStamps=1749229737 تکراری → رد شد.
# رکورد 947: TimeStamps=1749219267 تکراری → رد شد.
# رکورد 948: TimeStamps=1749205101 تکراری → رد شد.
# رکورد 949: TimeStamps=1749188953 تکراری → رد شد.
# رکورد 950: TimeStamps=1749172005 تکراری → رد شد.
# رکورد 951: TimeStamps=1749156408 تکراری → رد شد.
# رکورد 952: TimeStamps=1749143109 تکراری → رد شد.
# رکورد 953: TimeStamps=1749132036 تکراری → رد شد.
# رکورد 954: TimeStamps=1749112926 تکراری → رد شد.
# رکورد 955: TimeStamps=1749100322 تکراری → رد شد.
# رکورد 956: TimeStamps=1749088941 تکراری → رد شد.
# رکورد 957: TimeStamps=1749069872 تکراری → رد شد.
# رکورد 958: TimeStamps=1749056297 تکراری → رد شد.
# رکورد 959: TimeStamps=1749044797 تکراری → رد شد.
# رکورد 960: TimeStamps=1749026716 تکراری → رد شد.
# رکورد 961: TimeStamps=1749013346 تکراری → رد شد.
# رکورد 962: TimeStamps=1749003499 تکراری → رد شد.
# رکورد 963: TimeStamps=1748983136 تکراری → رد شد.
# رکورد 964: TimeStamps=1748971132 تکراری → رد شد.
# رکورد 965: TimeStamps=1748960146 تکراری → رد شد.
# رکورد 966: TimeStamps=1748939744 تکراری → رد شد.
# رکورد 967: TimeStamps=1748926836 تکراری → رد شد.
# رکورد 968: TimeStamps=1748916273 تکراری → رد شد.
# رکورد 969: TimeStamps=1748896939 تکراری → رد شد.
# رکورد 970: TimeStamps=1748885282 تکراری → رد شد.
# رکورد 971: TimeStamps=1748873009 تکراری → رد شد.
# رکورد 972: TimeStamps=1748853510 تکراری → رد شد.
# رکورد 973: TimeStamps=1748841557 تکراری → رد شد.
# رکورد 974: TimeStamps=1748824854 تکراری → رد شد.
# ...
# رکورد 10691: TimeStamps=1620027794 تکراری → رد شد.
# رکورد 10692: TimeStamps=1620016661 تکراری → رد شد.
# رکورد 10693: TimeStamps=1620002688 تکراری → رد شد.
# رکورد 10694: TimeStamps=1619992358 تکراری → رد شد.
# رکورد 10695: TimeStamps=1619980651 تکراری → رد شد.
# رکورد 10696: TimeStamps=1619971725 تکراری → رد شد.
# رکورد 10697: TimeStamps=1619959172 تکراری → رد شد.
# رکورد 10698: TimeStamps=1619948142 تکراری → رد شد.
# رکورد 10699: TimeStamps=1619938036 تکراری → رد شد.
# رکورد 10700: TimeStamps=1619929873 تکراری → رد شد.
# رکورد 10701: TimeStamps=1619916432 تکراری → رد شد.
# رکورد 10702: TimeStamps=1619906996 تکراری → رد شد.
# رکورد 10703: TimeStamps=1619895603 تکراری → رد شد.
# رکورد 10704: TimeStamps=1619885692 تکراری → رد شد.
# رکورد 10705: TimeStamps=1619876046 تکراری → رد شد.
# رکورد 10706: TimeStamps=1619862946 تکراری → رد شد.
# رکورد 10707: TimeStamps=1619855186 تکراری → رد شد.
# رکورد 10708: TimeStamps=1619844077 تکراری → رد شد.
# رکورد 10709: TimeStamps=1619830103 تکراری → رد شد.
# رکورد 10710: TimeStamps=1619822216 تکراری → رد شد.
# رکورد 10711: TimeStamps=1619808818 تکراری → رد شد.
# رکورد 10712: TimeStamps=1619798878 تکراری → رد شد.
# رکورد 10713: TimeStamps=1619786336 تکراری → رد شد.
# رکورد 10714: TimeStamps=1619776234 تکراری → رد شد.
# رکورد 10715: TimeStamps=1619765511 تکراری → رد شد.
# رکورد 10716: TimeStamps=1619755217 تکراری → رد شد.
# رکورد 10717: TimeStamps=1619742907 تکراری → رد شد.
# رکورد 10718: TimeStamps=1619732754 تکراری → رد شد.
# رکورد 10719: TimeStamps=1619721712 تکراری → رد شد.
# رکورد 10720: TimeStamps=1619712285 تکراری → رد شد.
# رکورد 10721: TimeStamps=1619699682 تکراری → رد شد.
# رکورد 10722: TimeStamps=1619690659 تکراری → رد شد.
# رکورد 10723: TimeStamps=1619681953 تکراری → رد شد.
# رکورد 10724: TimeStamps=1619669037 تکراری → رد شد.
# رکورد 10725: TimeStamps=1619657330 تکراری → رد شد.
# رکورد 10726: TimeStamps=1619646283 تکراری → رد شد.
# رکورد 10727: TimeStamps=1619635594 تکراری → رد شد.
# رکورد 10728: TimeStamps=1619624655 تکراری → رد شد.
# رکورد 10729: TimeStamps=1619613674 تکراری → رد شد.
# رکورد 10730: TimeStamps=1619603786 تکراری → رد شد.
# رکورد 10731: TimeStamps=1619593185 تکراری → رد شد.
# رکورد 10732: TimeStamps=1619584070 تکراری → رد شد.
# رکورد 10733: TimeStamps=1619571090 تکراری → رد شد.
# رکورد 10734: TimeStamps=1619561354 تکراری → رد شد.
# رکورد 10735: TimeStamps=1619549110 تکراری → رد شد.
# رکورد 10736: TimeStamps=1619539789 تکراری → رد شد.
# رکورد 10737: TimeStamps=1619528670 تکراری → رد شد.
# رکورد 10738: TimeStamps=1619516951 تکراری → رد شد.
# رکورد 10739: TimeStamps=1619506107 تکراری → رد شد.
# رکورد 10740: TimeStamps=1619495146 تکراری → رد شد.
# رکورد 10741: TimeStamps=1619487522 تکراری → رد شد.
# رکورد 10742: TimeStamps=1619476406 تکراری → رد شد.
# رکورد 10743: TimeStamps=1619463103 تکراری → رد شد.
# رکورد 10744: TimeStamps=1619454502 تکراری → رد شد.
# رکورد 10745: TimeStamps=1619441154 تکراری → رد شد.
# رکورد 10746: TimeStamps=1619431122 تکراری → رد شد.
# رکورد 10747: TimeStamps=1619420078 تکراری → رد شد.
# رکورد 10748: TimeStamps=1619398622 تکراری → رد شد.
# رکورد 10749: TimeStamps=1619387037 تکراری → رد شد.
# رکورد 10750: TimeStamps=1619375747 تکراری → رد شد.
# رکورد 10751: TimeStamps=1619367616 تکراری → رد شد.
# رکورد 10752: TimeStamps=1619357042 تکراری → رد شد.
# رکورد 10753: TimeStamps=1619344671 تکراری → رد شد.
# رکورد 10754: TimeStamps=1619336238 تکراری → رد شد.
# رکورد 10755: TimeStamps=1619324469 تکراری → رد شد.
# رکورد 10756: TimeStamps=1619312831 تکراری → رد شد.
# رکورد 10757: TimeStamps=1619300727 تکراری → رد شد.
# رکورد 10758: TimeStamps=1619289399 تکراری → رد شد.
# رکورد 10759: TimeStamps=1619279830 تکراری → رد شد.
# رکورد 10760: TimeStamps=1619268565 تکراری → رد شد.
# رکورد 10761: TimeStamps=1619257667 تکراری → رد شد.
# رکورد 10762: TimeStamps=1619246756 تکراری → رد شد.
# رکورد 10763: TimeStamps=1619238553 تکراری → رد شد.
# رکورد 10764: TimeStamps=1619225986 تکراری → رد شد.
# رکورد 10765: TimeStamps=1619215576 تکراری → رد شد.
# رکورد 10766: TimeStamps=1619203595 تکراری → رد شد.
# رکورد 10767: TimeStamps=1619195024 تکراری → رد شد.
# رکورد 10768: TimeStamps=1619182472 تکراری → رد شد.
# رکورد 10769: TimeStamps=1619171462 تکراری → رد شد.
# رکورد 10770: TimeStamps=1619160848 تکراری → رد شد.
# رکورد 10771: TimeStamps=1619151202 تکراری → رد شد.
# رکورد 10772: TimeStamps=1619139359 تکراری → رد شد.
# رکورد 10773: TimeStamps=1619131130 تکراری → رد شد.
# رکورد 10774: TimeStamps=1619117508 تکراری → رد شد.
# رکورد 10775: TimeStamps=1619107367 تکراری → رد شد.
# رکورد 10776: TimeStamps=1619096215 تکراری → رد شد.
# رکورد 10777: TimeStamps=1619086614 تکراری → رد شد.
# رکورد 10778: TimeStamps=1619073738 تکراری → رد شد.
# رکورد 10779: TimeStamps=1619062972 تکراری → رد شد.
# رکورد 10780: TimeStamps=1619052392 تکراری → رد شد.
# رکورد 10781: TimeStamps=1619042023 تکراری → رد شد.
# رکورد 10782: TimeStamps=1619031314 تکراری → رد شد.
# رکورد 10783: TimeStamps=1619020934 تکراری → رد شد.
# رکورد 10784: TimeStamps=1619011449 تکراری → رد شد.
# رکورد 10785: TimeStamps=1618998968 تکراری → رد شد.
# رکورد 10786: TimeStamps=1618988419 تکراری → رد شد.
# رکورد 10787: TimeStamps=1618978999 تکراری → رد شد.
# رکورد 10788: TimeStamps=1618965244 تکراری → رد شد.
# رکورد 10789: TimeStamps=1618955085 تکراری → رد شد.
# رکورد 10790: TimeStamps=1618944316 تکراری → رد شد.
# رکورد 10791: TimeStamps=1618935938 تکراری → رد شد.
# رکورد 10792: TimeStamps=1618922468 تکراری → رد شد.
# رکورد 10793: TimeStamps=1618911499 تکراری → رد شد.
# رکورد 10794: TimeStamps=1618903722 تکراری → رد شد.
# رکورد 10795: TimeStamps=1618892279 تکراری → رد شد.
# رکورد 10796: TimeStamps=1618880447 تکراری → رد شد.
# رکورد 10797: TimeStamps=1618871514 تکراری → رد شد.
# رکورد 10798: TimeStamps=1618857743 تکراری → رد شد.
# رکورد 10799: TimeStamps=1618850001 تکراری → رد شد.
# رکورد 10800: TimeStamps=1618836568 تکراری → رد شد.
# رکورد 10801: TimeStamps=1618825681 تکراری → رد شد.
# رکورد 10802: TimeStamps=1618815347 تکراری → رد شد.
# رکورد 10803: TimeStamps=1618804839 تکراری → رد شد.
# رکورد 10804: TimeStamps=1618793604 تکراری → رد شد.
# رکورد 10805: TimeStamps=1618785169 تکراری → رد شد.
# رکورد 10806: TimeStamps=1618771352 تکراری → رد شد.
# رکورد 10807: TimeStamps=1618762794 تکراری → رد شد.
# رکورد 10808: TimeStamps=1618750814 تکراری → رد شد.
# رکورد 10809: TimeStamps=1618740667 تکراری → رد شد.
# رکورد 10810: TimeStamps=1618729360 تکراری → رد شد.
# رکورد 10811: TimeStamps=1618719519 تکراری → رد شد.
# رکورد 10812: TimeStamps=1618706958 تکراری → رد شد.
# رکورد 10813: TimeStamps=1618696049 تکراری → رد شد.
# رکورد 10814: TimeStamps=1618685951 تکراری → رد شد.
# رکورد 10815: TimeStamps=1618676269 تکراری → رد شد.
# رکورد 10816: TimeStamps=1618665319 تکراری → رد شد.
# رکورد 10817: TimeStamps=1618654324 تکراری → رد شد.
# رکورد 10818: TimeStamps=1618644405 تکراری → رد شد.
# رکورد 10819: TimeStamps=1618632377 تکراری → رد شد.
# رکورد 10820: TimeStamps=1618621064 تکراری → رد شد.
# رکورد 10821: TimeStamps=1618610099 تکراری → رد شد.
# رکورد 10822: TimeStamps=1618598566 تکراری → رد شد.
# رکورد 10823: TimeStamps=1618588809 تکراری → رد شد.
# رکورد 10824: TimeStamps=1618578756 تکراری → رد شد.
# رکورد 10825: TimeStamps=1618565804 تکراری → رد شد.
# رکورد 10826: TimeStamps=1618557100 تکراری → رد شد.
# رکورد 10827: TimeStamps=1618545531 تکراری → رد شد.
# رکورد 10828: TimeStamps=1618536270 تکراری → رد شد.
# رکورد 10829: TimeStamps=1618523866 تکراری → رد شد.
# رکورد 10830: TimeStamps=1618513005 تکراری → رد شد.
# رکورد 10831: TimeStamps=1618503465 تکراری → رد شد.
# رکورد 10832: TimeStamps=1618492032 تکراری → رد شد.
# رکورد 10833: TimeStamps=1618479153 تکراری → رد شد.
# رکورد 10834: TimeStamps=1618469174 تکراری → رد شد.
# رکورد 10835: TimeStamps=1618460036 تکراری → رد شد.
# رکورد 10836: TimeStamps=1618447871 تکراری → رد شد.
# رکورد 10837: TimeStamps=1618436246 تکراری → رد شد.
# رکورد 10838: TimeStamps=1618425975 تکراری → رد شد.
# رکورد 10839: TimeStamps=1618415741 تکراری → رد شد.
# رکورد 10840: TimeStamps=1618404939 تکراری → رد شد.
# رکورد 10841: TimeStamps=1618394654 تکراری → رد شد.
# رکورد 10842: TimeStamps=1618384727 تکراری → رد شد.
# رکورد 10843: TimeStamps=1618374607 تکراری → رد شد.
# رکورد 10844: TimeStamps=1618362167 تکراری → رد شد.
# رکورد 10845: TimeStamps=1618352214 تکراری → رد شد.
# رکورد 10846: TimeStamps=1618339388 تکراری → رد شد.
# رکورد 10847: TimeStamps=1618329887 تکراری → رد شد.
# رکورد 10848: TimeStamps=1618318988 تکراری → رد شد.
# رکورد 10849: TimeStamps=1618307614 تکراری → رد شد.
# رکورد 10850: TimeStamps=1618298058 تکراری → رد شد.
# رکورد 10851: TimeStamps=1618286687 تکراری → رد شد.
# رکورد 10852: TimeStamps=1618275523 تکراری → رد شد.
# رکورد 10853: TimeStamps=1618263998 تکراری → رد شد.
# رکورد 10854: TimeStamps=1618253392 تکراری → رد شد.
# رکورد 10855: TimeStamps=1618243679 تکراری → رد شد.
# رکورد 10856: TimeStamps=1618232391 تکراری → رد شد.
# رکورد 10857: TimeStamps=1618222158 تکراری → رد شد.
# رکورد 10858: TimeStamps=1618210706 تکراری → رد شد.
# رکورد 10859: TimeStamps=1618202301 تکراری → رد شد.
# رکورد 10860: TimeStamps=1618189290 تکراری → رد شد.
# رکورد 10861: TimeStamps=1618177665 تکراری → رد شد.
# رکورد 10862: TimeStamps=1618168392 تکراری → رد شد.
# رکورد 10863: TimeStamps=1618156818 تکراری → رد شد.
# رکورد 10864: TimeStamps=1618145196 تکراری → رد شد.
# رکورد 10865: TimeStamps=1618134280 تکراری → رد شد.
# رکورد 10866: TimeStamps=1618124230 تکراری → رد شد.
# رکورد 10867: TimeStamps=1618113673 تکراری → رد شد.
# رکورد 10868: TimeStamps=1618105442 تکراری → رد شد.
# رکورد 10869: TimeStamps=1618091523 تکراری → رد شد.
# رکورد 10870: TimeStamps=1618080416 تکراری → رد شد.
# رکورد 10871: TimeStamps=1618071090 تکراری → رد شد.
# رکورد 10872: TimeStamps=1618060308 تکراری → رد شد.
# رکورد 10873: TimeStamps=1618049826 تکراری → رد شد.
# رکورد 10874: TimeStamps=1618039525 تکراری → رد شد.
# رکورد 10875: TimeStamps=1618027992 تکراری → رد شد.
# رکورد 10876: TimeStamps=1618016565 تکراری → رد شد.
# رکورد 10877: TimeStamps=1618005809 تکراری → رد شد.
# رکورد 10878: TimeStamps=1617993652 تکراری → رد شد.
# رکورد 10879: TimeStamps=1617984483 تکراری → رد شد.
# رکورد 10880: TimeStamps=1617974277 تکراری → رد شد.
# رکورد 10881: TimeStamps=1617962052 تکراری → رد شد.
# رکورد 10882: TimeStamps=1617952284 تکراری → رد شد.
# رکورد 10883: TimeStamps=1617942244 تکراری → رد شد.
# رکورد 10884: TimeStamps=1617929738 تکراری → رد شد.
# رکورد 10885: TimeStamps=1617918816 تکراری → رد شد.
# رکورد 10886: TimeStamps=1617907217 تکراری → رد شد.
# رکورد 10887: TimeStamps=1617897204 تکراری → رد شد.
# رکورد 10888: TimeStamps=1617885775 تکراری → رد شد.
# رکورد 10889: TimeStamps=1617874948 تکراری → رد شد.
# رکورد 10890: TimeStamps=1617864214 تکراری → رد شد.
# رکورد 10891: TimeStamps=1617855816 تکراری → رد شد.
# رکورد 10892: TimeStamps=1617843581 تکراری → رد شد.
# رکورد 10893: TimeStamps=1617833973 تکراری → رد شد.
# رکورد 10894: TimeStamps=1617821899 تکراری → رد شد.
# رکورد 10895: TimeStamps=1617811762 تکراری → رد شد.
# رکورد 10896: TimeStamps=1617801032 تکراری → رد شد.
# رکورد 10897: TimeStamps=1617790522 تکراری → رد شد.
# رکورد 10898: TimeStamps=1617779676 تکراری → رد شد.
# رکورد 10899: TimeStamps=1617770334 تکراری → رد شد.
# رکورد 10900: TimeStamps=1617759436 تکراری → رد شد.
# رکورد 10901: TimeStamps=1617747442 تکراری → رد شد.
# رکورد 10902: TimeStamps=1617735024 تکراری → رد شد.
# رکورد 10903: TimeStamps=1617725877 تکراری → رد شد.
# رکورد 10904: TimeStamps=1617712700 تکراری → رد شد.
# رکورد 10905: TimeStamps=1617702163 تکراری → رد شد.
# رکورد 10906: TimeStamps=1617692439 تکراری → رد شد.
# رکورد 10907: TimeStamps=1617682808 تکراری → رد شد.
# رکورد 10908: TimeStamps=1617669125 تکراری → رد شد.
# رکورد 10909: TimeStamps=1617658690 تکراری → رد شد.
# رکورد 10910: TimeStamps=1617648033 تکراری → رد شد.
# رکورد 10911: TimeStamps=1617638414 تکراری → رد شد.
# رکورد 10912: TimeStamps=1617628819 تکراری → رد شد.
# رکورد 10913: TimeStamps=1617617372 تکراری → رد شد.
# رکورد 10914: TimeStamps=1617605850 تکراری → رد شد.
# رکورد 10915: TimeStamps=1617594075 تکراری → رد شد.
# رکورد 10916: TimeStamps=1617583984 تکراری → رد شد.
# رکورد 10917: TimeStamps=1617572789 تکراری → رد شد.
# رکورد 10918: TimeStamps=1617562053 تکراری → رد شد.
# رکورد 10919: TimeStamps=1617552769 تکراری → رد شد.
# رکورد 10920: TimeStamps=1617541077 تکراری → رد شد.
# رکورد 10921: TimeStamps=1617529876 تکراری → رد شد.
# رکورد 10922: TimeStamps=1617518723 تکراری → رد شد.
# رکورد 10923: TimeStamps=1617511022 تکراری → رد شد.
# رکورد 10924: TimeStamps=1617496949 تکراری → رد شد.
# رکورد 10925: TimeStamps=1617486295 تکراری → رد شد.
# رکورد 10926: TimeStamps=1617476233 تکراری → رد شد.
# رکورد 10927: TimeStamps=1617465450 تکراری → رد شد.
# رکورد 10928: TimeStamps=1617453691 تکراری → رد شد.
# رکورد 10929: TimeStamps=1617443112 تکراری → رد شد.
# رکورد 10930: TimeStamps=1617432451 تکراری → رد شد.
# رکورد 10931: TimeStamps=1617422661 تکراری → رد شد.
# رکورد 10932: TimeStamps=1617410848 تکراری → رد شد.
# رکورد 10933: TimeStamps=1617401862 تکراری → رد شد.
# رکورد 10934: TimeStamps=1617388690 تکراری → رد شد.
# رکورد 10935: TimeStamps=1617378019 تکراری → رد شد.
# رکورد 10936: TimeStamps=1617315837 تکراری → رد شد.
# رکورد 10937: TimeStamps=1617303281 تکراری → رد شد.
# رکورد 10938: TimeStamps=1617292073 تکراری → رد شد.
# رکورد 10939: TimeStamps=1617282538 تکراری → رد شد.
# رکورد 10940: TimeStamps=1617259722 تکراری → رد شد.
# رکورد 10941: TimeStamps=1617250876 تکراری → رد شد.
# رکورد 10942: TimeStamps=1617239117 تکراری → رد شد.
# رکورد 10943: TimeStamps=1617227101 تکراری → رد شد.
# رکورد 10944: TimeStamps=1617216421 تکراری → رد شد.
# رکورد 10945: TimeStamps=1617206663 تکراری → رد شد.
# رکورد 10946: TimeStamps=1617194983 تکراری → رد شد.
# رکورد 10947: TimeStamps=1617183825 تکراری → رد شد.
# رکورد 10948: TimeStamps=1617172508 تکراری → رد شد.
# رکورد 10949: TimeStamps=1617163310 تکراری → رد شد.
# رکورد 10950: TimeStamps=1617067900 تکراری → رد شد.
# رکورد 10951: TimeStamps=1617055312 تکراری → رد شد.
# رکورد 10952: TimeStamps=1617042991 تکراری → رد شد.
# رکورد 10953: TimeStamps=1617034248 تکراری → رد شد.
# رکورد 10954: TimeStamps=1617022124 تکراری → رد شد.
# رکورد 10955: TimeStamps=1616990320 تکراری → رد شد.
# رکورد 10956: TimeStamps=1616937402 تکراری → رد شد.
# رکورد 10957: TimeStamps=1616926585 تکراری → رد شد.
# رکورد 10958: TimeStamps=1616915862 تکراری → رد شد.
# رکورد 10959: TimeStamps=1616905109 تکراری → رد شد.
# رکورد 10960: TimeStamps=1616870476 تکراری → رد شد.
# رکورد 10961: TimeStamps=1616699777 تکراری → رد شد.
# رکورد 10962: TimeStamps=1616688408 تکراری → رد شد.
# رکورد 10963: TimeStamps=1616675912 تکراری → رد شد.
# رکورد 10964: TimeStamps=1616666263 تکراری → رد شد.
# رکورد 10965: TimeStamps=1616655708 تکراری → رد شد.
# رکورد 10966: TimeStamps=1616645405 تکراری → رد شد.
# رکورد 10967: TimeStamps=1616632891 تکراری → رد شد.
# رکورد 10968: TimeStamps=1616622167 تکراری → رد شد.
# رکورد 10969: TimeStamps=1616610934 تکراری → رد شد.
# رکورد 10970: TimeStamps=1616600671 تکراری → رد شد.
# رکورد 10971: TimeStamps=1616591186 تکراری → رد شد.
# رکورد 10972: TimeStamps=1616579073 تکراری → رد شد.
# رکورد 10973: TimeStamps=1616568911 تکراری → رد شد.
# رکورد 10974: TimeStamps=1616558710 تکراری → رد شد.
# رکورد 10975: TimeStamps=1616546041 تکراری → رد شد.
# رکورد 10976: TimeStamps=1616536495 تکراری → رد شد.
# رکورد 10977: TimeStamps=1616527012 تکراری → رد شد.
# رکورد 10978: TimeStamps=1616514238 تکراری → رد شد.
# رکورد 10979: TimeStamps=1616504574 تکراری → رد شد.
# رکورد 10980: TimeStamps=1616492929 تکراری → رد شد.
# رکورد 10981: TimeStamps=1616482560 تکراری → رد شد.
# رکورد 10982: TimeStamps=1616471916 تکراری → رد شد.
# رکورد 10983: TimeStamps=1616460543 تکراری → رد شد.
# رکورد 10984: TimeStamps=1616449259 تکراری → رد شد.
# رکورد 10985: TimeStamps=1616439674 تکراری → رد شد.
# رکورد 10986: TimeStamps=1616428836 تکراری → رد شد.
# رکورد 10987: TimeStamps=1616417731 تکراری → رد شد.
# رکورد 10988: TimeStamps=1616394889 تکراری → رد شد.
# رکورد 10989: TimeStamps=1616388250 تکراری → رد شد.
# رکورد 10990: TimeStamps=1616373593 تکراری → رد شد.
# رکورد 10991: TimeStamps=1616363131 تکراری → رد شد.
# رکورد 10992: TimeStamps=1616357793 تکراری → رد شد.
# رکورد 10993: TimeStamps=1616346421 تکراری → رد شد.
# رکورد 10994: TimeStamps=1616323551 تکراری → رد شد.
# رکورد 10995: TimeStamps=1616303874 تکراری → رد شد.
# رکورد 10996: TimeStamps=1616292328 تکراری → رد شد.
# رکورد 10997: TimeStamps=1616280217 تکراری → رد شد.
# رکورد 10998: TimeStamps=1616270758 تکراری → رد شد.
# رکورد 10999: TimeStamps=1616262542 تکراری → رد شد.
# رکورد 11000: TimeStamps=1616144513 تکراری → رد شد.
# رکورد 11001: TimeStamps=1616057043 تکراری → رد شد.
# رکورد 11002: TimeStamps=1615972574 تکراری → رد شد.
#
# نتیجه این دور: 0 رکورد جدید درج و آپدیت شد.
# اسکریپت با موفقیت متوقف شد.
