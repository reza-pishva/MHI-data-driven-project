# %%
import pyodbc
import pymysql
import time
from datetime import datetime, timedelta
import signal
import sys

# ================== تنظیمات ==================
INTERVAL_SECONDS = 60 * 60  # هر 60 دقیقه یکبار
RUNNING = True

# ================== اتصالات ==================
def get_sql_connection():
    return pyodbc.connect(
        'DRIVER={SQL Server};'
        'SERVER=MKZ-DSAS\\DSAS;'
        'DATABASE=DSAS;'
        'UID=datadriven;'
        'PWD=5Rdx@4Rfv1355'
    )

def get_mysql_connection():
    return pymysql.connect(
        host="127.0.0.1",
        port=3306,
        user="root",
        password="",
        database="dsas",
        charset="utf8mb4",
        cursorclass=pymysql.cursors.DictCursor
    )

# ================== تنظیمات جدول CCW ==================
TABLE_NAME = "main_table_mhi_ccw_12"
UNIT_ID = 12
MAIN_ASSET_ID = 8330

# AssetIDهای فرعی (دقیقاً همان‌هایی که در SELECT شما هست)
SUB_ASSET_IDS = [8331, 8332, 8333, 8335, 8338, 8339]

# نگاشت AssetID → نام فیلد در MySQL
field_map = {aid: f"AssetID_{aid}" for aid in [MAIN_ASSET_ID] + SUB_ASSET_IDS}

# ================== تابع اصلی ==================
def run_task():
    print(f"\n{'='*90}")
    print(f" شروع اجرا: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f" جدول هدف: {TABLE_NAME}")
    print(f" unitID: {UNIT_ID} | AssetID اصلی: {MAIN_ASSET_ID}")
    print(f" AssetIDهای فرعی: {SUB_ASSET_IDS}")
    print(f"{'='*90}")

    conn_sql = None
    conn_mysql = None
    cursor_sql = None

    try:
        # اتصال‌ها
        print("اتصال به SQL Server...")
        conn_sql = get_sql_connection()
        cursor_sql = conn_sql.cursor()

        print("اتصال به MySQL...")
        conn_mysql = get_mysql_connection()

        # دریافت TimeStampsهای موجود
        print("در حال دریافت TimeStampsهای موجود در جدول MySQL...")
        existing_ts = set()
        with conn_mysql.cursor() as c:
            c.execute(f"SELECT TimeStamps FROM {TABLE_NAME} WHERE unitID = %s", (UNIT_ID,))
            for row in c.fetchall():
                if row['TimeStamps'] is not None:
                    existing_ts.add(row['TimeStamps'])
        print(f"تعداد رکورد موجود: {len(existing_ts):,} رکورد")

        # دریافت آخرین 12000 رکورد از AssetID اصلی
        print(f"در حال دریافت آخرین 12000 رکورد از AssetID={MAIN_ASSET_ID}...")
        query_main = """
            SELECT TOP 12000 [Value], [RecordTime], [RecordDate], [DateTime], [TimeStamp]
            FROM [DSAS].[PDA].[Periodic_Values]
            WHERE [UnitID] = ? AND [AssetID] = ?
            ORDER BY [DateTime] DESC
        """
        cursor_sql.execute(query_main, (UNIT_ID, MAIN_ASSET_ID))
        rows_main = cursor_sql.fetchall()

        if not rows_main:
            print(f"هیچ داده‌ای برای AssetID={MAIN_ASSET_ID} یافت نشد.")
            return

        inserted_count = 0
        for idx, row in enumerate(rows_main):
            ts = row.TimeStamp
            if ts in existing_ts:
                continue  # تکراری → رد کن (بدون پیام اضافی)

            dt = row.DateTime
            main_value = float(row.Value) if row.Value is not None else None

            print(f"\n{'─'*70}")
            print(f"درج رکورد جدید {idx+1:,} | TimeStamps: {ts} | {dt.strftime('%Y-%m-%d %H:%M:%S')}")

            # ۱. درج رکورد اصلی (فقط AssetID_8330 پر می‌شود)
            insert_sql = f"""
                INSERT INTO {TABLE_NAME} 
                (unitID, AssetID_8330, RecordTime, RecordDate, DateTime, TimeStamps)
                VALUES (%s, %s, %s, %s, %s, %s)
            """
            try:
                with conn_mysql.cursor() as c:
                    c.execute(insert_sql, (
                        UNIT_ID,
                        main_value,
                        dt.strftime('%H:%M:%S'),
                        dt.strftime('%Y-%m-%d'),
                        dt,
                        ts
                    ))
                conn_mysql.commit()
                inserted_count += 1
                print("رکورد اصلی با موفقیت درج شد.")
            except Exception as e:
                print(f"خطا در درج رکورد اصلی: {e}")
                conn_mysql.rollback()
                continue

            # ۲. پر کردن فیلدهای فرعی
            for aid in SUB_ASSET_IDS:
                field_name = field_map[aid]

                # جستجوی نزدیک (اختلاف ≤ 1000)
                near_sql = """
                    SELECT TOP 1 [Value]
                    FROM [DSAS].[PDA].[Periodic_Values]
                    WHERE [UnitID]=? AND [AssetID]=? AND ABS([TimeStamp] - ?) <= 1000
                    ORDER BY ABS([TimeStamp] - ?)
                """
                cursor_sql.execute(near_sql, (UNIT_ID, aid, ts, ts))
                near_row = cursor_sql.fetchone()

                if near_row and near_row.Value is not None:
                    value = float(near_row.Value)
                    source = "نزدیک"
                else:
                    # میانگین 10 مقدار آخر
                    avg_sql = """
                        SELECT AVG(CAST([Value] AS FLOAT))
                        FROM (
                            SELECT TOP 10 [Value]
                            FROM [DSAS].[PDA].[Periodic_Values]
                            WHERE [UnitID]=? AND [AssetID]=?
                            ORDER BY [DateTime] DESC
                        ) sub
                    """
                    cursor_sql.execute(avg_sql, (UNIT_ID, aid))
                    avg_row = cursor_sql.fetchone()
                    value = round(float(avg_row[0]), 4) if avg_row and avg_row[0] is not None else None
                    source = "میانگین 10 تایی"

                if value is not None:
                    update_sql = f"UPDATE {TABLE_NAME} SET {field_name} = %s WHERE TimeStamps = %s"
                    try:
                        with conn_mysql.cursor() as c:
                            c.execute(update_sql, (value, ts))
                        conn_mysql.commit()
                        print(f"   {field_name} = {value} ({source})")
                    except Exception as e:
                        print(f"   خطا در آپدیت {field_name}: {e}")
                        conn_mysql.rollback()
                else:
                    print(f"   {field_name}: مقدار یافت نشد.")

        print(f"\n{'='*90}")
        print(f"خلاصه اجرا: {inserted_count:,} رکورد جدید درج و آپدیت شد.")
        print(f"{'='*90}")

    except Exception as e:
        print(f"خطای کلی در اجرا: {e}")
    finally:
        if cursor_sql: cursor_sql.close()
        if conn_sql: conn_sql.close()
        if conn_mysql: conn_mysql.close()

# ================== توقف با Ctrl+C ==================
def signal_handler(sig, frame):
    global RUNNING
    print('\nدریافت Ctrl+C → در حال خروج از برنامه...')
    RUNNING = False
    sys.exit(0)

signal.signal(signal.SIGINT, signal_handler)

# ================== حلقه زمان‌بندی ==================
def scheduler():
    print("اسکریپت همگام‌سازی CCW شروع شد.")
    print("هر 60 دقیقه یکبار اجرا می‌شود. برای توقف Ctrl+C بزنید.\n")
    while RUNNING:
        run_task()
        if RUNNING:
            next_run = datetime.now() + timedelta(seconds=INTERVAL_SECONDS)
            print(f"\nمنتظر اجرای بعدی در {next_run.strftime('%Y-%m-%d %H:%M:%S')} ...")
            for _ in range(INTERVAL_SECONDS):
                if not RUNNING:
                    break
                time.sleep(1)

if __name__ == "__main__":
    scheduler()
# Out:
# اسکریپت همگام‌سازی CCW شروع شد.
# هر 60 دقیقه یکبار اجرا می‌شود. برای توقف Ctrl+C بزنید.
#
#
# ==========================================================================================
#  شروع اجرا: 2025-11-20 09:44:36
#  جدول هدف: main_table_mhi_ccw_12
#  unitID: 12 | AssetID اصلی: 8330
#  AssetIDهای فرعی: [8331, 8332, 8333, 8335, 8338, 8339]
# ==========================================================================================
# اتصال به SQL Server...
# اتصال به MySQL...
# در حال دریافت TimeStampsهای موجود در جدول MySQL...
# تعداد رکورد موجود: 0 رکورد
# در حال دریافت آخرین 12000 رکورد از AssetID=8330...
#
# ──────────────────────────────────────────────────────────────────────
# درج رکورد جدید 1 | TimeStamps: 1763605016 | 2025-11-20 05:46:56
# رکورد اصلی با موفقیت درج شد.
#    AssetID_8331 = 62.0 (نزدیک)
#    AssetID_8332 = 29.0 (نزدیک)
#    AssetID_8333 = 32.0 (نزدیک)
#    AssetID_8335 = 0.0 (نزدیک)
#    AssetID_8338 = 4.5 (نزدیک)
#    AssetID_8339 = 4.3 (نزدیک)
#
# ──────────────────────────────────────────────────────────────────────
# درج رکورد جدید 2 | TimeStamps: 1763585663 | 2025-11-20 00:24:23
# رکورد اصلی با موفقیت درج شد.
#    AssetID_8331 = 64.0 (نزدیک)
#    AssetID_8332 = 31.0 (نزدیک)
#    AssetID_8333 = 35.0 (نزدیک)
#    AssetID_8335 = 0.0 (نزدیک)
#    AssetID_8338 = 4.5 (نزدیک)
#    AssetID_8339 = 4.3 (نزدیک)
#
# ──────────────────────────────────────────────────────────────────────
# درج رکورد جدید 3 | TimeStamps: 1763571791 | 2025-11-19 20:33:11
# رکورد اصلی با موفقیت درج شد.
#    AssetID_8331 = 64.0 (نزدیک)
#    AssetID_8332 = 31.0 (نزدیک)
#    AssetID_8333 = 35.0 (نزدیک)
#    AssetID_8335 = 0.0 (نزدیک)
#    AssetID_8338 = 4.5 (نزدیک)
#    AssetID_8339 = 4.3 (نزدیک)
#
# ──────────────────────────────────────────────────────────────────────
# درج رکورد جدید 4 | TimeStamps: 1763556798 | 2025-11-19 16:23:18
# رکورد اصلی با موفقیت درج شد.
#    AssetID_8331 = 68.0 (نزدیک)
#    AssetID_8332 = 38.0 (نزدیک)
#    AssetID_8333 = 40.0 (نزدیک)
#    AssetID_8335 = 0.0 (نزدیک)
#    AssetID_8338 = 4.5 (نزدیک)
#    AssetID_8339 = 4.3 (نزدیک)
#
# ──────────────────────────────────────────────────────────────────────
# درج رکورد جدید 5 | TimeStamps: 1763541974 | 2025-11-19 12:16:14
# رکورد اصلی با موفقیت درج شد.
#    AssetID_8331 = 68.0 (نزدیک)
#    AssetID_8332 = 38.0 (نزدیک)
